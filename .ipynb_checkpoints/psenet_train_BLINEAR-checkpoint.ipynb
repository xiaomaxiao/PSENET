# %%
# %load_ext autoreload
# %autoreload 2 
# %matplotlib inline

# %%
import keras.backend.tensorflow_backend as KTF
import tensorflow as tf
config = tf.ConfigProto()  
config.gpu_options.allow_growth=True   
session = tf.Session(config=config)
KTF.set_session(session)
# Out:
# Using TensorFlow backend.

# %%
import keras 
from models.psenet import psenet

# %%
shape = (None,None,3)

# %%
inputs = keras.layers.Input(shape=shape)
output = psenet(inputs)
model  = keras.models.Model(inputs,output)
model.summary()
# Out:
# /anaconda3/envs/tf/lib/python3.5/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# (None, None)
# (None, None)
# (None, None)
# (None, None)
# (None, None)
# (None, None)
# (None, None)
# (None, None)
# (None, None)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 2 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 2 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 2 0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 2 524544      activation_49[0][0]
# __________________________________________________________________________________________________
# resize_image_1 (resize_image)   (None, None, None, 2 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 5 0           resize_image_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 589952      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 1 512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 1 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# resize_image_2 (resize_image)   (None, None, None, 1 0           activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 2 131328      activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 3 0           resize_image_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 1 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 1 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# resize_image_3 (resize_image)   (None, None, None, 1 0           activation_51[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 3 0           resize_image_3[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 1 442496      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 1 512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 1 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# resize_image_4 (resize_image)   (None, None, None, 1 0           activation_52[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, None, None, 1 0           resize_image_4[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 221312      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 1 512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# resize_image_5 (resize_image)   (None, None, None, 2 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# resize_image_6 (resize_image)   (None, None, None, 1 0           activation_50[0][0]
# __________________________________________________________________________________________________
# resize_image_7 (resize_image)   (None, None, None, 1 0           activation_51[0][0]
# __________________________________________________________________________________________________
# resize_image_8 (resize_image)   (None, None, None, 1 0           activation_52[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, None, None, 7 0           resize_image_5[0][0]
#                                                                  resize_image_6[0][0]
#                                                                  resize_image_7[0][0]
#                                                                  resize_image_8[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 2 1769728     concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 2 1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 2 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 6 1542        activation_54[0][0]
# __________________________________________________________________________________________________
# resize_image_9 (resize_image)   (None, None, None, 6 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 6 0           resize_image_9[0][0]
# ==================================================================================================
# Total params: 27,976,582
# Trainable params: 27,921,926
# Non-trainable params: 54,656
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam
from models.loss import build_loss
from models.metrics import build_iou,mean_iou
from keras.utils import multi_gpu_model

# %%
parallel_model = multi_gpu_model(model)

# %%
adam = Adam(1e-4)

# %%
ious = build_iou([0,1],['bk','txt'])

# %%
parallel_model.compile(loss=build_loss,
              optimizer=adam,
              metrics=ious)

# %%
import config 
from tool.generator import Generator

# %%
train_dir = config.MIWI_2018_TRAIN_LABEL_DIR
test_dir = config.MIWI_2018_TEST_LABEL_DIR
batch_size = 4
num_class =2 
shape = (640,640)

# %%
gen_train = Generator(train_dir,batch_size = batch_size ,istraining=True,num_classes=num_class,mirror = False,reshape=shape)

# %%
gen_test = Generator(test_dir,batch_size = batch_size ,istraining=False,num_classes=num_class,
                     reshape=shape,mirror=False,scale=False,clip=False,trans_color=False)

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
checkpoint = ModelCheckpoint(r'resent50-190219_BLINEAR-{epoch:02d}.hdf5',
                           save_weights_only=True)
tb = TensorBoard(log_dir='./logs', update_freq=10)

# %%
res = parallel_model.fit_generator(gen_train,
                          steps_per_epoch =gen_train.num_samples()// batch_size,
                          epochs = 40,
                          validation_data=gen_test,
                          validation_steps =gen_test.num_samples()//batch_size,
                          verbose=1,
                          initial_epoch=0,
                          workers=4,
                          max_queue_size=16,
                          callbacks=[checkpoint,tb])
# Out:
# Epoch 1/40
# 2255/2255 [==============================] - 2021s 896ms/step - loss: 0.2130 - iou_bk: 0.9275 - iou_txt: 0.6898 - val_loss: 0.1418 - val_iou_bk: 0.9499 - val_iou_txt: 0.7825
# Epoch 2/40
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.1731 - iou_bk: 0.9404 - iou_txt: 0.7373 - val_loss: 0.1311 - val_iou_bk: 0.9544 - val_iou_txt: 0.7960
# Epoch 3/40
# 2255/2255 [==============================] - 2004s 889ms/step - loss: 0.1666 - iou_bk: 0.9429 - iou_txt: 0.7453 - val_loss: 0.1379 - val_iou_bk: 0.9509 - val_iou_txt: 0.7877
# Epoch 4/40
# 2255/2255 [==============================] - 1988s 881ms/step - loss: 0.1573 - iou_bk: 0.9458 - iou_txt: 0.7576 - val_loss: 0.1264 - val_iou_bk: 0.9548 - val_iou_txt: 0.7924
# Epoch 5/40
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.1532 - iou_bk: 0.9470 - iou_txt: 0.7641 - val_loss: 0.1187 - val_iou_bk: 0.9585 - val_iou_txt: 0.8127
# Epoch 6/40
# 2255/2255 [==============================] - 1992s 884ms/step - loss: 0.1510 - iou_bk: 0.9489 - iou_txt: 0.7667 - val_loss: 0.1255 - val_iou_bk: 0.9554 - val_iou_txt: 0.8039
# Epoch 7/40
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.1464 - iou_bk: 0.9491 - iou_txt: 0.7734 - val_loss: 0.1253 - val_iou_bk: 0.9547 - val_iou_txt: 0.8037
# Epoch 8/40
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.1430 - iou_bk: 0.9506 - iou_txt: 0.7781 - val_loss: 0.1200 - val_iou_bk: 0.9570 - val_iou_txt: 0.8100
# Epoch 9/40
# 2255/2255 [==============================] - 1991s 883ms/step - loss: 0.1411 - iou_bk: 0.9511 - iou_txt: 0.7813 - val_loss: 0.1145 - val_iou_bk: 0.9597 - val_iou_txt: 0.8162
# Epoch 10/40
# 2255/2255 [==============================] - 2001s 888ms/step - loss: 0.1417 - iou_bk: 0.9511 - iou_txt: 0.7805 - val_loss: 0.1092 - val_iou_bk: 0.9615 - val_iou_txt: 0.8230
# Epoch 11/40
# 2255/2255 [==============================] - 2003s 888ms/step - loss: 0.1390 - iou_bk: 0.9515 - iou_txt: 0.7839 - val_loss: 0.1116 - val_iou_bk: 0.9605 - val_iou_txt: 0.8193
# Epoch 12/40
# 2255/2255 [==============================] - 2001s 887ms/step - loss: 0.1392 - iou_bk: 0.9526 - iou_txt: 0.7834 - val_loss: 0.1118 - val_iou_bk: 0.9608 - val_iou_txt: 0.8213
# Epoch 13/40
# 2255/2255 [==============================] - 2009s 891ms/step - loss: 0.1385 - iou_bk: 0.9527 - iou_txt: 0.7847 - val_loss: 0.1136 - val_iou_bk: 0.9600 - val_iou_txt: 0.8191
# Epoch 14/40
# 2255/2255 [==============================] - 2003s 888ms/step - loss: 0.1373 - iou_bk: 0.9527 - iou_txt: 0.7863 - val_loss: 0.1151 - val_iou_bk: 0.9584 - val_iou_txt: 0.8147
# Epoch 15/40
# 2255/2255 [==============================] - 1995s 885ms/step - loss: 0.1342 - iou_bk: 0.9540 - iou_txt: 0.7919 - val_loss: 0.1132 - val_iou_bk: 0.9617 - val_iou_txt: 0.8230
# Epoch 16/40
# 2255/2255 [==============================] - 1994s 884ms/step - loss: 0.1347 - iou_bk: 0.9550 - iou_txt: 0.7910 - val_loss: 0.1182 - val_iou_bk: 0.9592 - val_iou_txt: 0.8082
# Epoch 17/40
# 2255/2255 [==============================] - 1993s 884ms/step - loss: 0.1328 - iou_bk: 0.9545 - iou_txt: 0.7923 - val_loss: 0.1100 - val_iou_bk: 0.9611 - val_iou_txt: 0.8257
# Epoch 18/40
# 2255/2255 [==============================] - 1993s 884ms/step - loss: 0.1293 - iou_bk: 0.9558 - iou_txt: 0.7982 - val_loss: 0.1053 - val_iou_bk: 0.9637 - val_iou_txt: 0.8307
# Epoch 19/40
# 2255/2255 [==============================] - 1994s 884ms/step - loss: 0.1299 - iou_bk: 0.9555 - iou_txt: 0.7978 - val_loss: 0.1075 - val_iou_bk: 0.9629 - val_iou_txt: 0.8303
# Epoch 20/40
# 2255/2255 [==============================] - 2000s 887ms/step - loss: 0.1285 - iou_bk: 0.9554 - iou_txt: 0.7994 - val_loss: 0.1049 - val_iou_bk: 0.9636 - val_iou_txt: 0.8325
# Epoch 21/40
# 2255/2255 [==============================] - 1994s 884ms/step - loss: 0.1282 - iou_bk: 0.9556 - iou_txt: 0.7995 - val_loss: 0.1018 - val_iou_bk: 0.9645 - val_iou_txt: 0.8341
# Epoch 22/40
# 2255/2255 [==============================] - 1997s 885ms/step - loss: 0.1276 - iou_bk: 0.9568 - iou_txt: 0.8011 - val_loss: 0.1036 - val_iou_bk: 0.9632 - val_iou_txt: 0.8336
# Epoch 23/40
# 2255/2255 [==============================] - 2002s 888ms/step - loss: 0.1271 - iou_bk: 0.9566 - iou_txt: 0.8023 - val_loss: 0.1082 - val_iou_bk: 0.9617 - val_iou_txt: 0.8256
# Epoch 24/40
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.1267 - iou_bk: 0.9566 - iou_txt: 0.8018 - val_loss: 0.1075 - val_iou_bk: 0.9622 - val_iou_txt: 0.8281
# Epoch 25/40
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.1261 - iou_bk: 0.9573 - iou_txt: 0.8034 - val_loss: 0.1103 - val_iou_bk: 0.9613 - val_iou_txt: 0.8261
# Epoch 26/40
# 2255/2255 [==============================] - 2008s 890ms/step - loss: 0.1263 - iou_bk: 0.9570 - iou_txt: 0.8031 - val_loss: 0.1018 - val_iou_bk: 0.9642 - val_iou_txt: 0.8342
# Epoch 27/40
# 2255/2255 [==============================] - 1999s 887ms/step - loss: 0.1240 - iou_bk: 0.9574 - iou_txt: 0.8062 - val_loss: 0.1023 - val_iou_bk: 0.9640 - val_iou_txt: 0.8346
# Epoch 28/40
# 2255/2255 [==============================] - 1990s 882ms/step - loss: 0.1277 - iou_bk: 0.9556 - iou_txt: 0.8008 - val_loss: 0.1041 - val_iou_bk: 0.9636 - val_iou_txt: 0.8320
# Epoch 29/40
# 2255/2255 [==============================] - 1997s 886ms/step - loss: 0.1248 - iou_bk: 0.9572 - iou_txt: 0.8050 - val_loss: 0.1031 - val_iou_bk: 0.9639 - val_iou_txt: 0.8328
# Epoch 30/40
# 2255/2255 [==============================] - 1994s 884ms/step - loss: 0.1230 - iou_bk: 0.9580 - iou_txt: 0.8078 - val_loss: 0.1020 - val_iou_bk: 0.9642 - val_iou_txt: 0.8353
# Epoch 31/40
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.1246 - iou_bk: 0.9575 - iou_txt: 0.8051 - val_loss: 0.1018 - val_iou_bk: 0.9642 - val_iou_txt: 0.8347
# Epoch 32/40
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.1209 - iou_bk: 0.9594 - iou_txt: 0.8102 - val_loss: 0.1008 - val_iou_bk: 0.9646 - val_iou_txt: 0.8360
# Epoch 33/40
# 2255/2255 [==============================] - 1986s 881ms/step - loss: 0.1198 - iou_bk: 0.9587 - iou_txt: 0.8116 - val_loss: 0.1052 - val_iou_bk: 0.9625 - val_iou_txt: 0.8327
# Epoch 34/40
# 2255/2255 [==============================] - 1989s 882ms/step - loss: 0.1211 - iou_bk: 0.9583 - iou_txt: 0.8103 - val_loss: 0.1013 - val_iou_bk: 0.9649 - val_iou_txt: 0.8346
# Epoch 35/40
# 2255/2255 [==============================] - 1997s 886ms/step - loss: 0.1206 - iou_bk: 0.9586 - iou_txt: 0.8109 - val_loss: 0.1011 - val_iou_bk: 0.9639 - val_iou_txt: 0.8367
# Epoch 36/40
# 2255/2255 [==============================] - 1999s 887ms/step - loss: 0.1207 - iou_bk: 0.9589 - iou_txt: 0.8108 - val_loss: 0.1009 - val_iou_bk: 0.9647 - val_iou_txt: 0.8381
# Epoch 37/40
# 2255/2255 [==============================] - 1988s 881ms/step - loss: 0.1191 - iou_bk: 0.9596 - iou_txt: 0.8137 - val_loss: 0.1008 - val_iou_bk: 0.9646 - val_iou_txt: 0.8367
# Epoch 38/40
# 2255/2255 [==============================] - 1986s 881ms/step - loss: 0.1189 - iou_bk: 0.9592 - iou_txt: 0.8133 - val_loss: 0.1028 - val_iou_bk: 0.9638 - val_iou_txt: 0.8345
# Epoch 39/40
# 2255/2255 [==============================] - 2000s 887ms/step - loss: 0.1197 - iou_bk: 0.9592 - iou_txt: 0.8122 - val_loss: 0.1022 - val_iou_bk: 0.9647 - val_iou_txt: 0.8357
# Epoch 40/40
# 2255/2255 [==============================] - 1986s 881ms/step - loss: 0.1204 - iou_bk: 0.9590 - iou_txt: 0.8117 - val_loss: 0.1013 - val_iou_bk: 0.9644 - val_iou_txt: 0.8319

# %%
parallel_model.optimizer.lr = 1e-5
res = parallel_model.fit_generator(gen_train,
                          steps_per_epoch =gen_train.num_samples()// batch_size,
                          epochs = 70,
                          validation_data=gen_test,
                          validation_steps =gen_test.num_samples()//batch_size,
                          verbose=1,
                          initial_epoch=37,
                          workers=4,
                          max_queue_size=16,
                          callbacks=[checkpoint,tb])

# %%
parallel_model.optimizer.lr = 1e-6
res = parallel_model.fit_generator(gen_train,
                          steps_per_epoch =gen_train.num_samples()// batch_size,
                          epochs = 150,
                          validation_data=gen_test,
                          validation_steps =gen_test.num_samples()//batch_size,
                          verbose=1,
                          initial_epoch=70,
                          workers=4,
                          max_queue_size=16,
                          callbacks=[checkpoint,tb])
# Out:
# Epoch 71/150
# 2255/2255 [==============================] - 2020s 896ms/step - loss: 0.0888 - iou_bk: 0.9682 - iou_txt: 0.8549 - val_loss: 0.0912 - val_iou_bk: 0.9673 - val_iou_txt: 0.8504
# Epoch 72/150
# 2255/2255 [==============================] - 1989s 882ms/step - loss: 0.0878 - iou_bk: 0.9688 - iou_txt: 0.8565 - val_loss: 0.0895 - val_iou_bk: 0.9682 - val_iou_txt: 0.8525
# Epoch 73/150
# 2255/2255 [==============================] - 1999s 886ms/step - loss: 0.0879 - iou_bk: 0.9690 - iou_txt: 0.8567 - val_loss: 0.0905 - val_iou_bk: 0.9675 - val_iou_txt: 0.8499
# Epoch 74/150
# 2255/2255 [==============================] - 2019s 895ms/step - loss: 0.0898 - iou_bk: 0.9686 - iou_txt: 0.8532 - val_loss: 0.0920 - val_iou_bk: 0.9670 - val_iou_txt: 0.8502
# Epoch 75/150
# 2255/2255 [==============================] - 1995s 884ms/step - loss: 0.0879 - iou_bk: 0.9686 - iou_txt: 0.8568 - val_loss: 0.0890 - val_iou_bk: 0.9681 - val_iou_txt: 0.8541
# Epoch 76/150
# 2255/2255 [==============================] - 2003s 888ms/step - loss: 0.0872 - iou_bk: 0.9693 - iou_txt: 0.8579 - val_loss: 0.0901 - val_iou_bk: 0.9680 - val_iou_txt: 0.8526
# Epoch 77/150
# 2255/2255 [==============================] - 2001s 888ms/step - loss: 0.0875 - iou_bk: 0.9691 - iou_txt: 0.8570 - val_loss: 0.0895 - val_iou_bk: 0.9679 - val_iou_txt: 0.8529
# Epoch 78/150
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.0882 - iou_bk: 0.9692 - iou_txt: 0.8558 - val_loss: 0.0883 - val_iou_bk: 0.9686 - val_iou_txt: 0.8546
# Epoch 79/150
# 2255/2255 [==============================] - 1994s 884ms/step - loss: 0.0874 - iou_bk: 0.9688 - iou_txt: 0.8571 - val_loss: 0.0874 - val_iou_bk: 0.9689 - val_iou_txt: 0.8564
# Epoch 80/150
# 2255/2255 [==============================] - 2015s 893ms/step - loss: 0.0867 - iou_bk: 0.9695 - iou_txt: 0.8587 - val_loss: 0.0897 - val_iou_bk: 0.9678 - val_iou_txt: 0.8535
# Epoch 81/150
# 2255/2255 [==============================] - 1991s 883ms/step - loss: 0.0862 - iou_bk: 0.9696 - iou_txt: 0.8595 - val_loss: 0.0898 - val_iou_bk: 0.9679 - val_iou_txt: 0.8543
# Epoch 82/150
# 2255/2255 [==============================] - 2005s 889ms/step - loss: 0.0856 - iou_bk: 0.9697 - iou_txt: 0.8604 - val_loss: 0.0903 - val_iou_bk: 0.9673 - val_iou_txt: 0.8521
# Epoch 83/150
#    1/2255 [..............................] - ETA: 25:03 - loss: 0.0611 - iou_bk: 0.9668 - iou_txt: 0.9080
# C:\Program Files\Anaconda3\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.838847). Check your callbacks.
#   % delta_t_median)
# 2255/2255 [==============================] - 1997s 886ms/step - loss: 0.0885 - iou_bk: 0.9684 - iou_txt: 0.8555 - val_loss: 0.0876 - val_iou_bk: 0.9687 - val_iou_txt: 0.8558
# Epoch 84/150
# 2255/2255 [==============================] - 2003s 888ms/step - loss: 0.0874 - iou_bk: 0.9696 - iou_txt: 0.8574 - val_loss: 0.0864 - val_iou_bk: 0.9694 - val_iou_txt: 0.8579
# Epoch 85/150
# 2255/2255 [==============================] - 1991s 883ms/step - loss: 0.0850 - iou_bk: 0.9705 - iou_txt: 0.8616 - val_loss: 0.0856 - val_iou_bk: 0.9697 - val_iou_txt: 0.8587
# Epoch 86/150
# 2255/2255 [==============================] - 1990s 883ms/step - loss: 0.0861 - iou_bk: 0.9694 - iou_txt: 0.8593 - val_loss: 0.0872 - val_iou_bk: 0.9683 - val_iou_txt: 0.8557
# Epoch 87/150
# 2255/2255 [==============================] - 2021s 896ms/step - loss: 0.0861 - iou_bk: 0.9694 - iou_txt: 0.8597 - val_loss: 0.0903 - val_iou_bk: 0.9679 - val_iou_txt: 0.8536
# Epoch 88/150
# 2255/2255 [==============================] - 2001s 887ms/step - loss: 0.0857 - iou_bk: 0.9701 - iou_txt: 0.8603 - val_loss: 0.0872 - val_iou_bk: 0.9686 - val_iou_txt: 0.8548
# Epoch 89/150
# 2255/2255 [==============================] - 1993s 884ms/step - loss: 0.0858 - iou_bk: 0.9695 - iou_txt: 0.8600 - val_loss: 0.0871 - val_iou_bk: 0.9693 - val_iou_txt: 0.8564
# Epoch 90/150
# 2255/2255 [==============================] - 1985s 880ms/step - loss: 0.0859 - iou_bk: 0.9698 - iou_txt: 0.8603 - val_loss: 0.0878 - val_iou_bk: 0.9685 - val_iou_txt: 0.8550
# Epoch 91/150
# 2255/2255 [==============================] - 2021s 896ms/step - loss: 0.0849 - iou_bk: 0.9704 - iou_txt: 0.8614 - val_loss: 0.0912 - val_iou_bk: 0.9670 - val_iou_txt: 0.8488
# Epoch 92/150
# 2255/2255 [==============================] - 1993s 884ms/step - loss: 0.0848 - iou_bk: 0.9703 - iou_txt: 0.8615 - val_loss: 0.0900 - val_iou_bk: 0.9675 - val_iou_txt: 0.8519
# Epoch 93/150
#    2/2255 [..............................] - ETA: 26:02 - loss: 0.0738 - iou_bk: 0.9758 - iou_txt: 0.8750
# C:\Program Files\Anaconda3\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.987048). Check your callbacks.
#   % delta_t_median)
# 2255/2255 [==============================] - 2011s 892ms/step - loss: 0.0853 - iou_bk: 0.9699 - iou_txt: 0.8606 - val_loss: 0.0872 - val_iou_bk: 0.9693 - val_iou_txt: 0.8554
# Epoch 94/150
# 2255/2255 [==============================] - 1987s 881ms/step - loss: 0.0836 - iou_bk: 0.9710 - iou_txt: 0.8640 - val_loss: 0.0851 - val_iou_bk: 0.9697 - val_iou_txt: 0.8589
# Epoch 95/150
# 2255/2255 [==============================] - 2002s 888ms/step - loss: 0.0846 - iou_bk: 0.9702 - iou_txt: 0.8622 - val_loss: 0.0860 - val_iou_bk: 0.9692 - val_iou_txt: 0.8586
# Epoch 96/150
# 2255/2255 [==============================] - 2007s 890ms/step - loss: 0.0857 - iou_bk: 0.9697 - iou_txt: 0.8602 - val_loss: 0.0937 - val_iou_bk: 0.9668 - val_iou_txt: 0.8511
# Epoch 97/150
# 2255/2255 [==============================] - 1998s 886ms/step - loss: 0.0844 - iou_bk: 0.9705 - iou_txt: 0.8624 - val_loss: 0.0866 - val_iou_bk: 0.9694 - val_iou_txt: 0.8587
# Epoch 98/150
# 2255/2255 [==============================] - 2003s 888ms/step - loss: 0.0842 - iou_bk: 0.9702 - iou_txt: 0.8626 - val_loss: 0.0888 - val_iou_bk: 0.9682 - val_iou_txt: 0.8542
# Epoch 99/150
# 2255/2255 [==============================] - 1990s 883ms/step - loss: 0.0840 - iou_bk: 0.9703 - iou_txt: 0.8632 - val_loss: 0.0866 - val_iou_bk: 0.9691 - val_iou_txt: 0.8577
# Epoch 100/150
# 2255/2255 [==============================] - 1981s 879ms/step - loss: 0.0841 - iou_bk: 0.9706 - iou_txt: 0.8633 - val_loss: 0.0874 - val_iou_bk: 0.9693 - val_iou_txt: 0.8567
# Epoch 101/150
# 2255/2255 [==============================] - 2021s 896ms/step - loss: 0.0845 - iou_bk: 0.9701 - iou_txt: 0.8622 - val_loss: 0.0890 - val_iou_bk: 0.9682 - val_iou_txt: 0.8552
# Epoch 102/150
# 2255/2255 [==============================] - 1988s 882ms/step - loss: 0.0840 - iou_bk: 0.9706 - iou_txt: 0.8633 - val_loss: 0.0849 - val_iou_bk: 0.9699 - val_iou_txt: 0.8604
# Epoch 103/150
# 2255/2255 [==============================] - 1999s 886ms/step - loss: 0.0835 - iou_bk: 0.9707 - iou_txt: 0.8639 - val_loss: 0.0886 - val_iou_bk: 0.9673 - val_iou_txt: 0.8520
# Epoch 104/150
# 2255/2255 [==============================] - 2006s 890ms/step - loss: 0.0846 - iou_bk: 0.9701 - iou_txt: 0.8620 - val_loss: 0.0850 - val_iou_bk: 0.9696 - val_iou_txt: 0.8597
# Epoch 105/150
# 2255/2255 [==============================] - 1999s 886ms/step - loss: 0.0828 - iou_bk: 0.9706 - iou_txt: 0.8652 - val_loss: 0.0876 - val_iou_bk: 0.9687 - val_iou_txt: 0.8563
# Epoch 106/150
# 2255/2255 [==============================] - 2010s 891ms/step - loss: 0.0828 - iou_bk: 0.9711 - iou_txt: 0.8654 - val_loss: 0.0859 - val_iou_bk: 0.9698 - val_iou_txt: 0.8593
# Epoch 107/150
# 2255/2255 [==============================] - 1993s 884ms/step - loss: 0.0823 - iou_bk: 0.9710 - iou_txt: 0.8660 - val_loss: 0.0876 - val_iou_bk: 0.9684 - val_iou_txt: 0.8554
# Epoch 108/150
# 2255/2255 [==============================] - 1988s 882ms/step - loss: 0.0829 - iou_bk: 0.9710 - iou_txt: 0.8652 - val_loss: 0.0871 - val_iou_bk: 0.9690 - val_iou_txt: 0.8565
# Epoch 109/150
# 2255/2255 [==============================] - 2026s 899ms/step - loss: 0.0834 - iou_bk: 0.9702 - iou_txt: 0.8641 - val_loss: 0.0873 - val_iou_bk: 0.9687 - val_iou_txt: 0.8543
# Epoch 110/150
# 1327/2255 [================>.............] - ETA: 12:35 - loss: 0.0845 - iou_bk: 0.9705 - iou_txt: 0.8625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-a100095263ec> in <module>()
#       9                           workers=4,
#      10                           max_queue_size=16,
# ---> 11                           callbacks=[checkpoint,tb])
#
# C:\Program Files\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# C:\Program Files\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# C:\Program Files\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# C:\Program Files\Anaconda3\lib\site-packages\keras\utils\data_utils.py in get(self)
#     683         try:
#     684             while self.is_running():
# --> 685                 inputs = self.queue.get(block=True).get()
#     686                 self.queue.task_done()
#     687                 if inputs is not None:
#
# C:\Program Files\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# C:\Program Files\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# C:\Program Files\Anaconda3\lib\threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# C:\Program Files\Anaconda3\lib\threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %%
#model.load_weights('resent50-29.hdf5')
parallel_model.load_weights('resent50-190219_BLINEAR-102.hdf5')
model.save_weights('resent50-190219_BLINEAR-iou8604.hdf5')
model.load_weights('resent50-190219_BLINEAR-iou8604.hdf5')

# %%
model.load_weights('./tf/resnet50.hdf5')

# %%
import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np 
import os
import tqdm
#dir = r'C:\jianweidata\ocr\psenet\Extraction Test\2x'
dir = r'E:\psenet-MTWI\document\mtwi_2018_task2_test\icpr_mtwi_task2\image_test'
imagesfile = glob.glob(os.path.join(dir,'*.jpg'))
MIN_LEN = 640
MAX_LEN = 1024

# %%
from tool.utils import ufunc_4 , scale_expand_kernels ,fit_minarearectange,fit_boundingRect,save_MTWI_2108_resault
with tqdm.tqdm(total = len(imagesfile)) as bar:
    for i,j in enumerate(imagesfile):
                bar.update()
                #j = r'E:\psenet-MTWI\document\mtwi_2018_task2_test\icpr_mtwi_task2\image_test\T1..67FbxfXXXXXXXX_!!0-item_pic.jpg.jpg'
                images=cv2.imdecode(np.fromfile(j,dtype=np.uint8),-1) 
                #images=cv2.cvtColor(images,cv2.COLOR_RGB2BGR)
                
                h,w = images.shape[0:2]
#                 if(h>w and h>MAX_LEN):
#                     w = MAX_LEN / h * w   
#                     h = MAX_LEN
#                 elif(w>=h and w>MAX_LEN):
#                     h = MAX_LEN / w * h   
#                     w = MAX_LEN

                if(w<h and w<MIN_LEN):
                    h = MIN_LEN / w * h               
                    w = MIN_LEN
                elif(h<=w and h<MIN_LEN):
                    w = MIN_LEN / h * w         
                    h = MIN_LEN
                    
                w = min(w,MAX_LEN)    
                h = min(h,MAX_LEN)
                
                
                w = int(w //32 * 32)
                h = int(h//32 * 32)
                
#                 w = 640
#                 h = 640 
                scalex = images.shape[1] / w
                scaley = images.shape[0] / h
                
                images = cv2.resize(images,(w,h),cv2.INTER_AREA)
                images = np.reshape(images,(1,h,w,3))            
                
                res = model.predict(images)
                res1 = res[0]
                res1[res1>0.9]= 1
                res1[res1<=0.9]= 0
                newres1 = []
                for i in range(5):
                    n = np.logical_and(res1[:,:,5],res1[:,:,i]) * 255
                    newres1.append(n)
                newres1.append(res1[:,:,5]*255)
                num_label,labelimage = scale_expand_kernels(newres1)
                rects = fit_minarearectange(num_label,labelimage)

                
                cv2.drawContours(images[0],np.array(rects)*2,-1,(0,0,255),2)
                
                base_name = '.'.join(os.path.basename(j).split('.')[:-1])
                cv2.imwrite(os.path.join(dir,base_name+'_6.tif'),images[0])
                
                save_MTWI_2108_resault(os.path.join(dir,base_name+'.txt'),np.array(rects)*2,scalex ,scaley)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [32:16<00:00,  4.85it/s]

# %%
#images = cv2.imread('E:\psenet-MTWI\document\mtwi_2018_task2_test\icpr_mtwi_task2\image_test\TB107c7ejgy_uJjSZJnCczuOXXa.jpg')
imgsrc = cv2.imread('./tmp/t5.jpg')
h,w = imgsrc.shape[0:2]
images = np.copy(imgsrc)

MIN_LEN = 32
MAX_LEN = 1500
h, w = images.shape[0:2]
if(w<h):
    if(w<MIN_LEN):
        scale = 1.0 * MIN_LEN / w
        h = h * scale 
        w = MIN_LEN
    elif(h>MAX_LEN):
        scale = 1.0 * MAX_LEN / h 
        w = w * scale if w * scale > MIN_LEN else MIN_LEN
        h = MAX_LEN
elif(h<=w ):
    if(h<MIN_LEN):
        scale = 1.0 * MIN_LEN / h
        w = scale * w
        h = MIN_LEN 
    elif(w>MAX_LEN):
        scale = 1.0 * MAX_LEN / w
        h = scale * h if scale * h >  MIN_LEN else MIN_LEN
        w = MAX_LEN

w = int(w //32 * 32)
h = int(h//32 * 32)

scalex = images.shape[1] / w
scaley = images.shape[0] / h

images = cv2.resize(images,(w,h),cv2.INTER_AREA)
images = np.reshape(images,(1,h,w,3))

# %%
plt.imshow(images[0])

# %%
# %time res = model.predict(images[0:1,:,:,:])
# Out:
# CPU times: user 1min 29s, sys: 5.66 s, total: 1min 35s
# Wall time: 31.2 s

# %%
res1 = res[0]
res1[res1>0.5]= 1
res1[res1<=0.5]= 0
newres1 = []
for i in range(0,5):
    n = np.logical_and(res1[:,:,5],res1[:,:,i]) * 255
    n = n.astype('int32')
    newres1.append(n)
newres1.append((res1[:,:,5]*255).astype('int32'))

# %%
plt.imshow(newres1[-1],cmap='gray')

# %%
t_img = newres1[-1]
from tool.utils import calc_vote_angle
angle = calc_vote_angle(t_img)

# %%
print(angle)
# Out:
# 5.0

# %%
from tool.utils import ufunc_4 , scale_expand_kernels , fit_boundingRect_cpp ,fit_minarearectange_cpp
from tool.utils import text_porposcal , order_points

# %%
newres1[-1].dtype
# Out:
# dtype('int32')

# %%
# %time num_label,labelimage = scale_expand_kernels(newres1,filter=False)
# Out:
# CPU times: user 21.8 ms, sys: 2.66 ms, total: 24.5 ms
# Wall time: 24.5 ms

# %%
#纠偏
labelimage = labelimage.astype(np.uint8)
h,w = labelimage.shape[0:2]
M = cv2.getRotationMatrix2D((w/2,h/2),angle,1.0)
labelimage = cv2.warpAffine(labelimage,M,(w,h),borderMode = cv2.INTER_NEAREST,borderValue=0)

# %%
plt.imshow(labelimage)

# %%
from tool.pse import find_label_coord
def fit_boundingRect_warp_cpp(num_label,labelimage,M):
    rects = [] 
    points = find_label_coord(labelimage,num_label)
    for i in range(num_label):
        pt = np.array(points[i]).reshape(-1,2)
        
        x,y,w,h = cv2.boundingRect(pt)
        print(x,y,w,h)
        rects.append(np.array([[x,y],[x+w,y],[x+w,y+h],[x,y+h]]))
    return rects

# %%
# %time rects = fit_boundingRect_cpp1(num_label-1,labelimage)
plt.imshow(labelimage)
# Out:
# 124 36 345 571
# 125 37 341 569
# 125 37 343 570
# 125 37 343 567
# 125 37 343 563
# 125 43 343 562
# 125 43 343 564
# 125 102 320 503
# 125 195 320 411
# 126 196 318 410
# 126 196 318 395
# 126 223 318 370
# 126 223 318 383
# 126 223 318 368
# 127 223 317 383
# 126 223 318 382
# 126 224 318 376
# 126 251 318 355
# 126 278 275 328
# 126 280 276 306
# 127 305 276 301
# 126 305 276 302
# 127 332 277 266
# 127 334 278 267
# 127 360 277 246
# 198 360 206 242
# 247 360 156 243
# 269 362 135 237
# 263 429 143 177
# 267 428 136 173
# 263 443 138 163
# 288 467 119 127
# 287 499 121 88
# 287 494 111 112
# 304 494 100 112
# 304 509 104 96
# 305 514 98 92
# 303 525 102 69
# 314 525 88 70
# 326 529 70 77
# 317 531 91 75
# 317 531 91 73
# 322 540 67 64
# 315 575 72 31
# 318 574 70 26
# 319 576 70 30
# 315 586 52 20
# CPU times: user 27.7 ms, sys: 7.04 ms, total: 34.8 ms
# Wall time: 30 ms

# %%
print(rects)
# Out:
# [array([[124,  36],
#        [469,  36],
#        [469, 607],
#        [124, 607]]), array([[125,  37],
#        [466,  37],
#        [466, 606],
#        [125, 606]]), array([[125,  37],
#        [468,  37],
#        [468, 607],
#        [125, 607]]), array([[125,  37],
#        [468,  37],
#        [468, 604],
#        [125, 604]]), array([[125,  37],
#        [468,  37],
#        [468, 600],
#        [125, 600]]), array([[125,  43],
#        [468,  43],
#        [468, 605],
#        [125, 605]]), array([[125,  43],
#        [468,  43],
#        [468, 607],
#        [125, 607]]), array([[125, 102],
#        [445, 102],
#        [445, 605],
#        [125, 605]]), array([[125, 195],
#        [445, 195],
#        [445, 606],
#        [125, 606]]), array([[126, 196],
#        [444, 196],
#        [444, 606],
#        [126, 606]]), array([[126, 196],
#        [444, 196],
#        [444, 591],
#        [126, 591]]), array([[126, 223],
#        [444, 223],
#        [444, 593],
#        [126, 593]]), array([[126, 223],
#        [444, 223],
#        [444, 606],
#        [126, 606]]), array([[126, 223],
#        [444, 223],
#        [444, 591],
#        [126, 591]]), array([[127, 223],
#        [444, 223],
#        [444, 606],
#        [127, 606]]), array([[126, 223],
#        [444, 223],
#        [444, 605],
#        [126, 605]]), array([[126, 224],
#        [444, 224],
#        [444, 600],
#        [126, 600]]), array([[126, 251],
#        [444, 251],
#        [444, 606],
#        [126, 606]]), array([[126, 278],
#        [401, 278],
#        [401, 606],
#        [126, 606]]), array([[126, 280],
#        [402, 280],
#        [402, 586],
#        [126, 586]]), array([[127, 305],
#        [403, 305],
#        [403, 606],
#        [127, 606]]), array([[126, 305],
#        [402, 305],
#        [402, 607],
#        [126, 607]]), array([[127, 332],
#        [404, 332],
#        [404, 598],
#        [127, 598]]), array([[127, 334],
#        [405, 334],
#        [405, 601],
#        [127, 601]]), array([[127, 360],
#        [404, 360],
#        [404, 606],
#        [127, 606]]), array([[198, 360],
#        [404, 360],
#        [404, 602],
#        [198, 602]]), array([[247, 360],
#        [403, 360],
#        [403, 603],
#        [247, 603]]), array([[269, 362],
#        [404, 362],
#        [404, 599],
#        [269, 599]]), array([[263, 429],
#        [406, 429],
#        [406, 606],
#        [263, 606]]), array([[267, 428],
#        [403, 428],
#        [403, 601],
#        [267, 601]]), array([[263, 443],
#        [401, 443],
#        [401, 606],
#        [263, 606]]), array([[288, 467],
#        [407, 467],
#        [407, 594],
#        [288, 594]]), array([[287, 499],
#        [408, 499],
#        [408, 587],
#        [287, 587]]), array([[287, 494],
#        [398, 494],
#        [398, 606],
#        [287, 606]]), array([[304, 494],
#        [404, 494],
#        [404, 606],
#        [304, 606]]), array([[304, 509],
#        [408, 509],
#        [408, 605],
#        [304, 605]]), array([[305, 514],
#        [403, 514],
#        [403, 606],
#        [305, 606]]), array([[303, 525],
#        [405, 525],
#        [405, 594],
#        [303, 594]]), array([[314, 525],
#        [402, 525],
#        [402, 595],
#        [314, 595]]), array([[326, 529],
#        [396, 529],
#        [396, 606],
#        [326, 606]]), array([[317, 531],
#        [408, 531],
#        [408, 606],
#        [317, 606]]), array([[317, 531],
#        [408, 531],
#        [408, 604],
#        [317, 604]]), array([[322, 540],
#        [389, 540],
#        [389, 604],
#        [322, 604]]), array([[315, 575],
#        [387, 575],
#        [387, 606],
#        [315, 606]]), array([[318, 574],
#        [388, 574],
#        [388, 600],
#        [318, 600]]), array([[319, 576],
#        [389, 576],
#        [389, 606],
#        [319, 606]]), array([[315, 586],
#        [367, 586],
#        [367, 606],
#        [315, 606]])]

# %%
rects = order_points(rects)

# %%
imagetest = np.copy(images[0])
for id,rt in enumerate(rects):
    try:
        cv2.putText(imagetest,str(id),(rt[0][0]*2,rt[0][1]*2),cv2.FONT_HERSHEY_COMPLEX,0.2,(0,255,0),2)
        cv2.drawContours(imagetest,[rt*2],-1,(0,255,0),1)
    except Exception as e :
        pass

# %%
g = text_porposcal(rects,labelimage.shape[1],max_dist=100,threshold_overlap_v=0.6)
rects = g.get_text_line()
for rt in rects:
    try:
        cv2.drawContours(imagetest,[rt*2],-1,(0,0,255),2)
    except Exception as e :
        pass
# Out:
# (36, 2)
# [[124  36]
#  [469  36]
#  [469 607]
#  [124 607]
#  [125  37]
#  [466  37]
#  [466 606]
#  [125 606]
#  [126 196]
#  [444 196]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (32, 2)
# [[125  37]
#  [468  37]
#  [468 607]
#  [125 607]
#  [126 196]
#  [444 196]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (32, 2)
# [[125  37]
#  [468  37]
#  [468 604]
#  [125 604]
#  [126 196]
#  [444 196]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (32, 2)
# [[125  37]
#  [468  37]
#  [468 600]
#  [125 600]
#  [126 196]
#  [444 196]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (32, 2)
# [[125  43]
#  [468  43]
#  [468 605]
#  [125 605]
#  [126 196]
#  [444 196]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (32, 2)
# [[125  43]
#  [468  43]
#  [468 607]
#  [125 607]
#  [126 196]
#  [444 196]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (32, 2)
# [[125 102]
#  [445 102]
#  [445 605]
#  [125 605]
#  [126 196]
#  [444 196]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (32, 2)
# [[125 195]
#  [445 195]
#  [445 606]
#  [125 606]
#  [126 196]
#  [444 196]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 196]
#  [444 196]
#  [444 591]
#  [126 591]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 223]
#  [444 223]
#  [444 593]
#  [126 593]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 223]
#  [444 223]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 223]
#  [444 223]
#  [444 591]
#  [126 591]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 223]
#  [444 223]
#  [444 605]
#  [126 605]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 224]
#  [444 224]
#  [444 600]
#  [126 600]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 251]
#  [444 251]
#  [444 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 278]
#  [401 278]
#  [401 606]
#  [126 606]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 280]
#  [402 280]
#  [402 586]
#  [126 586]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (24, 2)
# [[127 305]
#  [403 305]
#  [403 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (28, 2)
# [[126 305]
#  [402 305]
#  [402 607]
#  [126 607]
#  [127 223]
#  [444 223]
#  [444 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (24, 2)
# [[127 332]
#  [404 332]
#  [404 598]
#  [127 598]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (24, 2)
# [[127 334]
#  [405 334]
#  [405 601]
#  [127 601]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (24, 2)
# [[127 360]
#  [404 360]
#  [404 606]
#  [127 606]
#  [198 360]
#  [404 360]
#  [404 602]
#  [198 602]
#  [247 360]
#  [403 360]
#  [403 603]
#  [247 603]
#  [263 429]
#  [406 429]
#  [406 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (12, 2)
# [[263 443]
#  [401 443]
#  [401 606]
#  [263 606]
#  [267 428]
#  [403 428]
#  [403 601]
#  [267 601]
#  [269 362]
#  [404 362]
#  [404 599]
#  [269 599]]
# (32, 2)
# [[287 499]
#  [408 499]
#  [408 587]
#  [287 587]
#  [288 467]
#  [407 467]
#  [407 594]
#  [288 594]
#  [304 494]
#  [404 494]
#  [404 606]
#  [304 606]
#  [305 514]
#  [403 514]
#  [403 606]
#  [305 606]
#  [314 525]
#  [402 525]
#  [402 595]
#  [314 595]
#  [317 531]
#  [408 531]
#  [408 606]
#  [317 606]
#  [322 540]
#  [389 540]
#  [389 604]
#  [322 604]
#  [326 529]
#  [396 529]
#  [396 606]
#  [326 606]]
# (32, 2)
# [[287 494]
#  [398 494]
#  [398 606]
#  [287 606]
#  [288 467]
#  [407 467]
#  [407 594]
#  [288 594]
#  [304 494]
#  [404 494]
#  [404 606]
#  [304 606]
#  [305 514]
#  [403 514]
#  [403 606]
#  [305 606]
#  [314 525]
#  [402 525]
#  [402 595]
#  [314 595]
#  [317 531]
#  [408 531]
#  [408 606]
#  [317 606]
#  [322 540]
#  [389 540]
#  [389 604]
#  [322 604]
#  [326 529]
#  [396 529]
#  [396 606]
#  [326 606]]
# (24, 2)
# [[304 509]
#  [408 509]
#  [408 605]
#  [304 605]
#  [305 514]
#  [403 514]
#  [403 606]
#  [305 606]
#  [314 525]
#  [402 525]
#  [402 595]
#  [314 595]
#  [317 531]
#  [408 531]
#  [408 606]
#  [317 606]
#  [322 540]
#  [389 540]
#  [389 604]
#  [322 604]
#  [326 529]
#  [396 529]
#  [396 606]
#  [326 606]]
# (28, 2)
# [[303 525]
#  [405 525]
#  [405 594]
#  [303 594]
#  [304 494]
#  [404 494]
#  [404 606]
#  [304 606]
#  [305 514]
#  [403 514]
#  [403 606]
#  [305 606]
#  [314 525]
#  [402 525]
#  [402 595]
#  [314 595]
#  [317 531]
#  [408 531]
#  [408 606]
#  [317 606]
#  [322 540]
#  [389 540]
#  [389 604]
#  [322 604]
#  [326 529]
#  [396 529]
#  [396 606]
#  [326 606]]
# (12, 2)
# [[317 531]
#  [408 531]
#  [408 604]
#  [317 604]
#  [322 540]
#  [389 540]
#  [389 604]
#  [322 604]
#  [326 529]
#  [396 529]
#  [396 606]
#  [326 606]]
# (12, 2)
# [[315 575]
#  [387 575]
#  [387 606]
#  [315 606]
#  [318 574]
#  [388 574]
#  [388 600]
#  [318 600]
#  [319 576]
#  [389 576]
#  [389 606]
#  [319 606]]
# (8, 2)
# [[315 586]
#  [367 586]
#  [367 606]
#  [315 606]
#  [319 576]
#  [389 576]
#  [389 606]
#  [319 606]]

# %%
rects.shape
# Out:
# (30, 4, 2)

# %%
plt.imshow(imagetest)
cv2.imwrite('./tmp/t1.jpg',imagetest)
# Out:
# True

# %%
for rt in rects:
    rt[0] = rt[0] * 2 * scalex
    rt[1] = rt[1] * 2 * scaley
    rt[2] = rt[2] * 2 * scalex 
    rt[3] = rt[3] * 2 * scaley

# %%
imagetest = np.copy(imgsrc)
for rt in rects:
    cv2.rectangle(imagetest,(rt[0],rt[1]),(rt[2],rt[3]),(0,0,255),1)
plt.imshow(imagetest)
cv2.imwrite('./tmp/test7_1.jpg',imagetest)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-31e8aed2f714> in <module>
#       1 imagetest = np.copy(imgsrc)
#       2 for rt in rects:
# ----> 3     cv2.rectangle(imagetest,(rt[0],rt[1]),(rt[2],rt[3]),(0,0,255),1)
#       4 plt.imshow(imagetest)
#       5 cv2.imwrite('./tmp/test7_1.jpg',imagetest)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
scalex
# Out:
# 0.75625

# %%
h = r'E:\psenet-MTWI\document\mtwi_2018_task2_test\icpr_mtwi_task2\image_test\LB1gXi2JVXXXXXUXFXXXXXXXXXX.jpg'
images=cv2.imdecode(np.fromfile(h,dtype=np.uint8),-1) 
#images=cv2.cvtColor(images,cv2.COLOR_RGB2BGR)
cv2.imwrite(r'E:\tmp.jpg',images)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-66-99067a8deb6f> in <module>
#       1 h = r'E:\psenet-MTWI\document\mtwi_2018_task2_test\icpr_mtwi_task2\image_test\LB1gXi2JVXXXXXUXFXXXXXXXXXX.jpg'
# ----> 2 images=cv2.imdecode(np.fromfile(h,dtype=np.uint8),-1)
#       3 #images=cv2.cvtColor(images,cv2.COLOR_RGB2BGR)
#       4 cv2.imwrite(r'E:\tmp.jpg',images)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\psenet-MTWI\\document\\mtwi_2018_task2_test\\icpr_mtwi_task2\\image_test\\LB1gXi2JVXXXXXUXFXXXXXXXXXX.jpg'

# %%
## todo
* 大概有100张图片没读出来 Y
* 把评测代码加上       
* 换backone
* 弧形文本行
* 强交叉文本行
* 误检太多
# Out:
#   File "<ipython-input-54-adbc9f38b16f>", line 2
#     * 大概有100张图片没读出来 Y
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 转pb

# %%
saver = tf.train.Saver()
saver.save(KTF.get_session(),r'./tf/resnet50.ckpt')
# Out:
# 'tf/resnet50.ckpt'

# %%
n = [print(n.name) for n in tf.get_default_graph().as_graph_def().node]
# Out:
# input_1
# lambda_1/MeanSubstraction/y
# lambda_1/MeanSubstraction
# conv1_pad/Pad/paddings
# conv1_pad/Pad
# conv1/truncated_normal/shape
# conv1/truncated_normal/mean
# conv1/truncated_normal/stddev
# conv1/truncated_normal/TruncatedNormal
# conv1/truncated_normal/mul
# conv1/truncated_normal
# conv1/kernel
# conv1/kernel/Assign
# conv1/kernel/read
# conv1/Const
# conv1/bias
# conv1/bias/Assign
# conv1/bias/read
# conv1/convolution/dilation_rate
# conv1/convolution
# conv1/BiasAdd
# bn_conv1/Const
# bn_conv1/gamma
# bn_conv1/gamma/Assign
# bn_conv1/gamma/read
# bn_conv1/Const_1
# bn_conv1/beta
# bn_conv1/beta/Assign
# bn_conv1/beta/read
# bn_conv1/Const_2
# bn_conv1/moving_mean
# bn_conv1/moving_mean/Assign
# bn_conv1/moving_mean/read
# bn_conv1/Const_3
# bn_conv1/moving_variance
# bn_conv1/moving_variance/Assign
# bn_conv1/moving_variance/read
# bn_conv1/IsVariableInitialized
# bn_conv1/IsVariableInitialized_1
# bn_conv1/IsVariableInitialized_2
# bn_conv1/IsVariableInitialized_3
# bn_conv1/IsVariableInitialized_4
# bn_conv1/IsVariableInitialized_5
# bn_conv1/init
# bn_conv1/Const_4
# bn_conv1/Const_5
# bn_conv1/FusedBatchNorm
# bn_conv1/Shape
# bn_conv1/strided_slice/stack
# bn_conv1/strided_slice/stack_1
# bn_conv1/strided_slice/stack_2
# bn_conv1/strided_slice
# bn_conv1/Shape_1
# bn_conv1/strided_slice_1/stack
# bn_conv1/strided_slice_1/stack_1
# bn_conv1/strided_slice_1/stack_2
# bn_conv1/strided_slice_1
# bn_conv1/Shape_2
# bn_conv1/strided_slice_2/stack
# bn_conv1/strided_slice_2/stack_1
# bn_conv1/strided_slice_2/stack_2
# bn_conv1/strided_slice_2
# bn_conv1/Rank/packed
# bn_conv1/Rank
# bn_conv1/range/start
# bn_conv1/range/delta
# bn_conv1/range
# bn_conv1/Prod/input
# bn_conv1/Prod
# bn_conv1/Cast
# bn_conv1/sub/y
# bn_conv1/sub
# bn_conv1/truediv
# bn_conv1/mul
# bn_conv1/AssignMovingAvg/decay
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/zeros
# bn_conv1/moving_mean/biased
# bn_conv1/moving_mean/biased/Assign
# bn_conv1/moving_mean/biased/read
# bn_conv1/moving_mean/local_step/Initializer/zeros
# bn_conv1/moving_mean/local_step
# bn_conv1/moving_mean/local_step/Assign
# bn_conv1/moving_mean/local_step/read
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/sub
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/mul
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/bn_conv1/moving_mean
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/AssignAdd/value
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/AssignAdd
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/read
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/sub_1/x
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/sub_1
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/read_1
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/Pow
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/sub_2/x
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/sub_2
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/truediv
# bn_conv1/AssignMovingAvg/bn_conv1/moving_mean/sub_3
# bn_conv1/AssignMovingAvg
# bn_conv1/AssignMovingAvg_1/decay
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/zeros
# bn_conv1/moving_variance/biased
# bn_conv1/moving_variance/biased/Assign
# bn_conv1/moving_variance/biased/read
# bn_conv1/moving_variance/local_step/Initializer/zeros
# bn_conv1/moving_variance/local_step
# bn_conv1/moving_variance/local_step/Assign
# bn_conv1/moving_variance/local_step/read
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/sub
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/mul
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/bn_conv1/moving_variance
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/AssignAdd/value
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/AssignAdd
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/read
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/sub_1/x
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/sub_1
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/read_1
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/Pow
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/sub_2/x
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/sub_2
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/truediv
# bn_conv1/AssignMovingAvg_1/bn_conv1/moving_variance/sub_3
# bn_conv1/AssignMovingAvg_1
# bn_conv1/keras_learning_phase/input
# bn_conv1/keras_learning_phase
# bn_conv1/cond/Switch
# bn_conv1/cond/switch_t
# bn_conv1/cond/switch_f
# bn_conv1/cond/pred_id
# bn_conv1/cond/Switch_1
# bn_conv1/cond/FusedBatchNorm
# bn_conv1/cond/FusedBatchNorm/Switch
# bn_conv1/cond/FusedBatchNorm/Switch_1
# bn_conv1/cond/FusedBatchNorm/Switch_2
# bn_conv1/cond/FusedBatchNorm/Switch_3
# bn_conv1/cond/FusedBatchNorm/Switch_4
# bn_conv1/cond/Merge
# activation_1/Relu
# pool1_pad/Pad/paddings
# pool1_pad/Pad
# max_pooling2d_1/MaxPool
# res2a_branch2a/truncated_normal/shape
# res2a_branch2a/truncated_normal/mean
# res2a_branch2a/truncated_normal/stddev
# res2a_branch2a/truncated_normal/TruncatedNormal
# res2a_branch2a/truncated_normal/mul
# res2a_branch2a/truncated_normal
# res2a_branch2a/kernel
# res2a_branch2a/kernel/Assign
# res2a_branch2a/kernel/read
# res2a_branch2a/Const
# res2a_branch2a/bias
# res2a_branch2a/bias/Assign
# res2a_branch2a/bias/read
# res2a_branch2a/convolution/dilation_rate
# res2a_branch2a/convolution
# res2a_branch2a/BiasAdd
# bn2a_branch2a/Const
# bn2a_branch2a/gamma
# bn2a_branch2a/gamma/Assign
# bn2a_branch2a/gamma/read
# bn2a_branch2a/Const_1
# bn2a_branch2a/beta
# bn2a_branch2a/beta/Assign
# bn2a_branch2a/beta/read
# bn2a_branch2a/Const_2
# bn2a_branch2a/moving_mean
# bn2a_branch2a/moving_mean/Assign
# bn2a_branch2a/moving_mean/read
# bn2a_branch2a/Const_3
# bn2a_branch2a/moving_variance
# bn2a_branch2a/moving_variance/Assign
# bn2a_branch2a/moving_variance/read
# bn2a_branch2a/Const_4
# bn2a_branch2a/Const_5
# bn2a_branch2a/FusedBatchNorm
# bn2a_branch2a/Shape
# bn2a_branch2a/strided_slice/stack
# bn2a_branch2a/strided_slice/stack_1
# bn2a_branch2a/strided_slice/stack_2
# bn2a_branch2a/strided_slice
# bn2a_branch2a/Shape_1
# bn2a_branch2a/strided_slice_1/stack
# bn2a_branch2a/strided_slice_1/stack_1
# bn2a_branch2a/strided_slice_1/stack_2
# bn2a_branch2a/strided_slice_1
# bn2a_branch2a/Shape_2
# bn2a_branch2a/strided_slice_2/stack
# bn2a_branch2a/strided_slice_2/stack_1
# bn2a_branch2a/strided_slice_2/stack_2
# bn2a_branch2a/strided_slice_2
# bn2a_branch2a/Rank/packed
# bn2a_branch2a/Rank
# bn2a_branch2a/range/start
# bn2a_branch2a/range/delta
# bn2a_branch2a/range
# bn2a_branch2a/Prod/input
# bn2a_branch2a/Prod
# bn2a_branch2a/Cast
# bn2a_branch2a/sub/y
# bn2a_branch2a/sub
# bn2a_branch2a/truediv
# bn2a_branch2a/mul
# bn2a_branch2a/AssignMovingAvg/decay
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/zeros
# bn2a_branch2a/moving_mean/biased
# bn2a_branch2a/moving_mean/biased/Assign
# bn2a_branch2a/moving_mean/biased/read
# bn2a_branch2a/moving_mean/local_step/Initializer/zeros
# bn2a_branch2a/moving_mean/local_step
# bn2a_branch2a/moving_mean/local_step/Assign
# bn2a_branch2a/moving_mean/local_step/read
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/sub
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/mul
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/bn2a_branch2a/moving_mean
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/AssignAdd/value
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/AssignAdd
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/read
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/sub_1/x
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/sub_1
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/read_1
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/Pow
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/sub_2/x
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/sub_2
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/truediv
# bn2a_branch2a/AssignMovingAvg/bn2a_branch2a/moving_mean/sub_3
# bn2a_branch2a/AssignMovingAvg
# bn2a_branch2a/AssignMovingAvg_1/decay
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/zeros
# bn2a_branch2a/moving_variance/biased
# bn2a_branch2a/moving_variance/biased/Assign
# bn2a_branch2a/moving_variance/biased/read
# bn2a_branch2a/moving_variance/local_step/Initializer/zeros
# bn2a_branch2a/moving_variance/local_step
# bn2a_branch2a/moving_variance/local_step/Assign
# bn2a_branch2a/moving_variance/local_step/read
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/sub
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/mul
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/bn2a_branch2a/moving_variance
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/AssignAdd/value
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/AssignAdd
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/read
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/sub_1/x
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/sub_1
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/read_1
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/Pow
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/sub_2/x
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/sub_2
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/truediv
# bn2a_branch2a/AssignMovingAvg_1/bn2a_branch2a/moving_variance/sub_3
# bn2a_branch2a/AssignMovingAvg_1
# bn2a_branch2a/cond/Switch
# bn2a_branch2a/cond/switch_t
# bn2a_branch2a/cond/switch_f
# bn2a_branch2a/cond/pred_id
# bn2a_branch2a/cond/Switch_1
# bn2a_branch2a/cond/FusedBatchNorm
# bn2a_branch2a/cond/FusedBatchNorm/Switch
# bn2a_branch2a/cond/FusedBatchNorm/Switch_1
# bn2a_branch2a/cond/FusedBatchNorm/Switch_2
# bn2a_branch2a/cond/FusedBatchNorm/Switch_3
# bn2a_branch2a/cond/FusedBatchNorm/Switch_4
# bn2a_branch2a/cond/Merge
# activation_2/Relu
# res2a_branch2b/truncated_normal/shape
# res2a_branch2b/truncated_normal/mean
# res2a_branch2b/truncated_normal/stddev
# res2a_branch2b/truncated_normal/TruncatedNormal
# res2a_branch2b/truncated_normal/mul
# res2a_branch2b/truncated_normal
# res2a_branch2b/kernel
# res2a_branch2b/kernel/Assign
# res2a_branch2b/kernel/read
# res2a_branch2b/Const
# res2a_branch2b/bias
# res2a_branch2b/bias/Assign
# res2a_branch2b/bias/read
# res2a_branch2b/convolution/dilation_rate
# res2a_branch2b/convolution
# res2a_branch2b/BiasAdd
# bn2a_branch2b/Const
# bn2a_branch2b/gamma
# bn2a_branch2b/gamma/Assign
# bn2a_branch2b/gamma/read
# bn2a_branch2b/Const_1
# bn2a_branch2b/beta
# bn2a_branch2b/beta/Assign
# bn2a_branch2b/beta/read
# bn2a_branch2b/Const_2
# bn2a_branch2b/moving_mean
# bn2a_branch2b/moving_mean/Assign
# bn2a_branch2b/moving_mean/read
# bn2a_branch2b/Const_3
# bn2a_branch2b/moving_variance
# bn2a_branch2b/moving_variance/Assign
# bn2a_branch2b/moving_variance/read
# bn2a_branch2b/Const_4
# bn2a_branch2b/Const_5
# bn2a_branch2b/FusedBatchNorm
# bn2a_branch2b/Shape
# bn2a_branch2b/strided_slice/stack
# bn2a_branch2b/strided_slice/stack_1
# bn2a_branch2b/strided_slice/stack_2
# bn2a_branch2b/strided_slice
# bn2a_branch2b/Shape_1
# bn2a_branch2b/strided_slice_1/stack
# bn2a_branch2b/strided_slice_1/stack_1
# bn2a_branch2b/strided_slice_1/stack_2
# bn2a_branch2b/strided_slice_1
# bn2a_branch2b/Shape_2
# bn2a_branch2b/strided_slice_2/stack
# bn2a_branch2b/strided_slice_2/stack_1
# bn2a_branch2b/strided_slice_2/stack_2
# bn2a_branch2b/strided_slice_2
# bn2a_branch2b/Rank/packed
# bn2a_branch2b/Rank
# bn2a_branch2b/range/start
# bn2a_branch2b/range/delta
# bn2a_branch2b/range
# bn2a_branch2b/Prod/input
# bn2a_branch2b/Prod
# bn2a_branch2b/Cast
# bn2a_branch2b/sub/y
# bn2a_branch2b/sub
# bn2a_branch2b/truediv
# bn2a_branch2b/mul
# bn2a_branch2b/AssignMovingAvg/decay
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/zeros
# bn2a_branch2b/moving_mean/biased
# bn2a_branch2b/moving_mean/biased/Assign
# bn2a_branch2b/moving_mean/biased/read
# bn2a_branch2b/moving_mean/local_step/Initializer/zeros
# bn2a_branch2b/moving_mean/local_step
# bn2a_branch2b/moving_mean/local_step/Assign
# bn2a_branch2b/moving_mean/local_step/read
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/sub
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/mul
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/bn2a_branch2b/moving_mean
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/AssignAdd/value
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/AssignAdd
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/read
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/sub_1/x
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/sub_1
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/read_1
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/Pow
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/sub_2/x
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/sub_2
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/truediv
# bn2a_branch2b/AssignMovingAvg/bn2a_branch2b/moving_mean/sub_3
# bn2a_branch2b/AssignMovingAvg
# bn2a_branch2b/AssignMovingAvg_1/decay
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/zeros
# bn2a_branch2b/moving_variance/biased
# bn2a_branch2b/moving_variance/biased/Assign
# bn2a_branch2b/moving_variance/biased/read
# bn2a_branch2b/moving_variance/local_step/Initializer/zeros
# bn2a_branch2b/moving_variance/local_step
# bn2a_branch2b/moving_variance/local_step/Assign
# bn2a_branch2b/moving_variance/local_step/read
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/sub
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/mul
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/bn2a_branch2b/moving_variance
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/AssignAdd/value
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/AssignAdd
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/read
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/sub_1/x
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/sub_1
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/read_1
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/Pow
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/sub_2/x
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/sub_2
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/truediv
# bn2a_branch2b/AssignMovingAvg_1/bn2a_branch2b/moving_variance/sub_3
# bn2a_branch2b/AssignMovingAvg_1
# bn2a_branch2b/cond/Switch
# bn2a_branch2b/cond/switch_t
# bn2a_branch2b/cond/switch_f
# bn2a_branch2b/cond/pred_id
# bn2a_branch2b/cond/Switch_1
# bn2a_branch2b/cond/FusedBatchNorm
# bn2a_branch2b/cond/FusedBatchNorm/Switch
# bn2a_branch2b/cond/FusedBatchNorm/Switch_1
# bn2a_branch2b/cond/FusedBatchNorm/Switch_2
# bn2a_branch2b/cond/FusedBatchNorm/Switch_3
# bn2a_branch2b/cond/FusedBatchNorm/Switch_4
# bn2a_branch2b/cond/Merge
# activation_3/Relu
# res2a_branch2c/truncated_normal/shape
# res2a_branch2c/truncated_normal/mean
# res2a_branch2c/truncated_normal/stddev
# res2a_branch2c/truncated_normal/TruncatedNormal
# res2a_branch2c/truncated_normal/mul
# res2a_branch2c/truncated_normal
# res2a_branch2c/kernel
# res2a_branch2c/kernel/Assign
# res2a_branch2c/kernel/read
# res2a_branch2c/Const
# res2a_branch2c/bias
# res2a_branch2c/bias/Assign
# res2a_branch2c/bias/read
# res2a_branch2c/convolution/dilation_rate
# res2a_branch2c/convolution
# res2a_branch2c/BiasAdd
# bn2a_branch2c/Const
# bn2a_branch2c/gamma
# bn2a_branch2c/gamma/Assign
# bn2a_branch2c/gamma/read
# bn2a_branch2c/Const_1
# bn2a_branch2c/beta
# bn2a_branch2c/beta/Assign
# bn2a_branch2c/beta/read
# bn2a_branch2c/Const_2
# bn2a_branch2c/moving_mean
# bn2a_branch2c/moving_mean/Assign
# bn2a_branch2c/moving_mean/read
# bn2a_branch2c/Const_3
# bn2a_branch2c/moving_variance
# bn2a_branch2c/moving_variance/Assign
# bn2a_branch2c/moving_variance/read
# bn2a_branch2c/Const_4
# bn2a_branch2c/Const_5
# bn2a_branch2c/FusedBatchNorm
# bn2a_branch2c/Shape
# bn2a_branch2c/strided_slice/stack
# bn2a_branch2c/strided_slice/stack_1
# bn2a_branch2c/strided_slice/stack_2
# bn2a_branch2c/strided_slice
# bn2a_branch2c/Shape_1
# bn2a_branch2c/strided_slice_1/stack
# bn2a_branch2c/strided_slice_1/stack_1
# bn2a_branch2c/strided_slice_1/stack_2
# bn2a_branch2c/strided_slice_1
# bn2a_branch2c/Shape_2
# bn2a_branch2c/strided_slice_2/stack
# bn2a_branch2c/strided_slice_2/stack_1
# bn2a_branch2c/strided_slice_2/stack_2
# bn2a_branch2c/strided_slice_2
# bn2a_branch2c/Rank/packed
# bn2a_branch2c/Rank
# bn2a_branch2c/range/start
# bn2a_branch2c/range/delta
# bn2a_branch2c/range
# bn2a_branch2c/Prod/input
# bn2a_branch2c/Prod
# bn2a_branch2c/Cast
# bn2a_branch2c/sub/y
# bn2a_branch2c/sub
# bn2a_branch2c/truediv
# bn2a_branch2c/mul
# bn2a_branch2c/AssignMovingAvg/decay
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/zeros
# bn2a_branch2c/moving_mean/biased
# bn2a_branch2c/moving_mean/biased/Assign
# bn2a_branch2c/moving_mean/biased/read
# bn2a_branch2c/moving_mean/local_step/Initializer/zeros
# bn2a_branch2c/moving_mean/local_step
# bn2a_branch2c/moving_mean/local_step/Assign
# bn2a_branch2c/moving_mean/local_step/read
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/sub
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/mul
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/bn2a_branch2c/moving_mean
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/AssignAdd/value
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/AssignAdd
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/read
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/sub_1/x
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/sub_1
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/read_1
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/Pow
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/sub_2/x
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/sub_2
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/truediv
# bn2a_branch2c/AssignMovingAvg/bn2a_branch2c/moving_mean/sub_3
# bn2a_branch2c/AssignMovingAvg
# bn2a_branch2c/AssignMovingAvg_1/decay
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/zeros
# bn2a_branch2c/moving_variance/biased
# bn2a_branch2c/moving_variance/biased/Assign
# bn2a_branch2c/moving_variance/biased/read
# bn2a_branch2c/moving_variance/local_step/Initializer/zeros
# bn2a_branch2c/moving_variance/local_step
# bn2a_branch2c/moving_variance/local_step/Assign
# bn2a_branch2c/moving_variance/local_step/read
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/sub
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/mul
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/bn2a_branch2c/moving_variance
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/AssignAdd/value
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/AssignAdd
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/read
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/sub_1/x
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/sub_1
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/read_1
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/Pow
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/sub_2/x
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/sub_2
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/truediv
# bn2a_branch2c/AssignMovingAvg_1/bn2a_branch2c/moving_variance/sub_3
# bn2a_branch2c/AssignMovingAvg_1
# bn2a_branch2c/cond/Switch
# bn2a_branch2c/cond/switch_t
# bn2a_branch2c/cond/switch_f
# bn2a_branch2c/cond/pred_id
# bn2a_branch2c/cond/Switch_1
# bn2a_branch2c/cond/FusedBatchNorm
# bn2a_branch2c/cond/FusedBatchNorm/Switch
# bn2a_branch2c/cond/FusedBatchNorm/Switch_1
# bn2a_branch2c/cond/FusedBatchNorm/Switch_2
# bn2a_branch2c/cond/FusedBatchNorm/Switch_3
# bn2a_branch2c/cond/FusedBatchNorm/Switch_4
# bn2a_branch2c/cond/Merge
# res2a_branch1/truncated_normal/shape
# res2a_branch1/truncated_normal/mean
# res2a_branch1/truncated_normal/stddev
# res2a_branch1/truncated_normal/TruncatedNormal
# res2a_branch1/truncated_normal/mul
# res2a_branch1/truncated_normal
# res2a_branch1/kernel
# res2a_branch1/kernel/Assign
# res2a_branch1/kernel/read
# res2a_branch1/Const
# res2a_branch1/bias
# res2a_branch1/bias/Assign
# res2a_branch1/bias/read
# res2a_branch1/convolution/dilation_rate
# res2a_branch1/convolution
# res2a_branch1/BiasAdd
# bn2a_branch1/Const
# bn2a_branch1/gamma
# bn2a_branch1/gamma/Assign
# bn2a_branch1/gamma/read
# bn2a_branch1/Const_1
# bn2a_branch1/beta
# bn2a_branch1/beta/Assign
# bn2a_branch1/beta/read
# bn2a_branch1/Const_2
# bn2a_branch1/moving_mean
# bn2a_branch1/moving_mean/Assign
# bn2a_branch1/moving_mean/read
# bn2a_branch1/Const_3
# bn2a_branch1/moving_variance
# bn2a_branch1/moving_variance/Assign
# bn2a_branch1/moving_variance/read
# bn2a_branch1/Const_4
# bn2a_branch1/Const_5
# bn2a_branch1/FusedBatchNorm
# bn2a_branch1/Shape
# bn2a_branch1/strided_slice/stack
# bn2a_branch1/strided_slice/stack_1
# bn2a_branch1/strided_slice/stack_2
# bn2a_branch1/strided_slice
# bn2a_branch1/Shape_1
# bn2a_branch1/strided_slice_1/stack
# bn2a_branch1/strided_slice_1/stack_1
# bn2a_branch1/strided_slice_1/stack_2
# bn2a_branch1/strided_slice_1
# bn2a_branch1/Shape_2
# bn2a_branch1/strided_slice_2/stack
# bn2a_branch1/strided_slice_2/stack_1
# bn2a_branch1/strided_slice_2/stack_2
# bn2a_branch1/strided_slice_2
# bn2a_branch1/Rank/packed
# bn2a_branch1/Rank
# bn2a_branch1/range/start
# bn2a_branch1/range/delta
# bn2a_branch1/range
# bn2a_branch1/Prod/input
# bn2a_branch1/Prod
# bn2a_branch1/Cast
# bn2a_branch1/sub/y
# bn2a_branch1/sub
# bn2a_branch1/truediv
# bn2a_branch1/mul
# bn2a_branch1/AssignMovingAvg/decay
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/zeros
# bn2a_branch1/moving_mean/biased
# bn2a_branch1/moving_mean/biased/Assign
# bn2a_branch1/moving_mean/biased/read
# bn2a_branch1/moving_mean/local_step/Initializer/zeros
# bn2a_branch1/moving_mean/local_step
# bn2a_branch1/moving_mean/local_step/Assign
# bn2a_branch1/moving_mean/local_step/read
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/sub
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/mul
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/bn2a_branch1/moving_mean
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/AssignAdd/value
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/AssignAdd
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/read
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/sub_1/x
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/sub_1
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/read_1
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/Pow
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/sub_2/x
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/sub_2
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/truediv
# bn2a_branch1/AssignMovingAvg/bn2a_branch1/moving_mean/sub_3
# bn2a_branch1/AssignMovingAvg
# bn2a_branch1/AssignMovingAvg_1/decay
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/zeros
# bn2a_branch1/moving_variance/biased
# bn2a_branch1/moving_variance/biased/Assign
# bn2a_branch1/moving_variance/biased/read
# bn2a_branch1/moving_variance/local_step/Initializer/zeros
# bn2a_branch1/moving_variance/local_step
# bn2a_branch1/moving_variance/local_step/Assign
# bn2a_branch1/moving_variance/local_step/read
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/sub
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/mul
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/bn2a_branch1/moving_variance
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/AssignAdd/value
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/AssignAdd
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/read
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/sub_1/x
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/sub_1
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/read_1
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/Pow
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/sub_2/x
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/sub_2
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/truediv
# bn2a_branch1/AssignMovingAvg_1/bn2a_branch1/moving_variance/sub_3
# bn2a_branch1/AssignMovingAvg_1
# bn2a_branch1/cond/Switch
# bn2a_branch1/cond/switch_t
# bn2a_branch1/cond/switch_f
# bn2a_branch1/cond/pred_id
# bn2a_branch1/cond/Switch_1
# bn2a_branch1/cond/FusedBatchNorm
# bn2a_branch1/cond/FusedBatchNorm/Switch
# bn2a_branch1/cond/FusedBatchNorm/Switch_1
# bn2a_branch1/cond/FusedBatchNorm/Switch_2
# bn2a_branch1/cond/FusedBatchNorm/Switch_3
# bn2a_branch1/cond/FusedBatchNorm/Switch_4
# bn2a_branch1/cond/Merge
# add_1/add
# activation_4/Relu
# res2b_branch2a/truncated_normal/shape
# res2b_branch2a/truncated_normal/mean
# res2b_branch2a/truncated_normal/stddev
# res2b_branch2a/truncated_normal/TruncatedNormal
# res2b_branch2a/truncated_normal/mul
# res2b_branch2a/truncated_normal
# res2b_branch2a/kernel
# res2b_branch2a/kernel/Assign
# res2b_branch2a/kernel/read
# res2b_branch2a/Const
# res2b_branch2a/bias
# res2b_branch2a/bias/Assign
# res2b_branch2a/bias/read
# res2b_branch2a/convolution/dilation_rate
# res2b_branch2a/convolution
# res2b_branch2a/BiasAdd
# bn2b_branch2a/Const
# bn2b_branch2a/gamma
# bn2b_branch2a/gamma/Assign
# bn2b_branch2a/gamma/read
# bn2b_branch2a/Const_1
# bn2b_branch2a/beta
# bn2b_branch2a/beta/Assign
# bn2b_branch2a/beta/read
# bn2b_branch2a/Const_2
# bn2b_branch2a/moving_mean
# bn2b_branch2a/moving_mean/Assign
# bn2b_branch2a/moving_mean/read
# bn2b_branch2a/Const_3
# bn2b_branch2a/moving_variance
# bn2b_branch2a/moving_variance/Assign
# bn2b_branch2a/moving_variance/read
# bn2b_branch2a/Const_4
# bn2b_branch2a/Const_5
# bn2b_branch2a/FusedBatchNorm
# bn2b_branch2a/Shape
# bn2b_branch2a/strided_slice/stack
# bn2b_branch2a/strided_slice/stack_1
# bn2b_branch2a/strided_slice/stack_2
# bn2b_branch2a/strided_slice
# bn2b_branch2a/Shape_1
# bn2b_branch2a/strided_slice_1/stack
# bn2b_branch2a/strided_slice_1/stack_1
# bn2b_branch2a/strided_slice_1/stack_2
# bn2b_branch2a/strided_slice_1
# bn2b_branch2a/Shape_2
# bn2b_branch2a/strided_slice_2/stack
# bn2b_branch2a/strided_slice_2/stack_1
# bn2b_branch2a/strided_slice_2/stack_2
# bn2b_branch2a/strided_slice_2
# bn2b_branch2a/Rank/packed
# bn2b_branch2a/Rank
# bn2b_branch2a/range/start
# bn2b_branch2a/range/delta
# bn2b_branch2a/range
# bn2b_branch2a/Prod/input
# bn2b_branch2a/Prod
# bn2b_branch2a/Cast
# bn2b_branch2a/sub/y
# bn2b_branch2a/sub
# bn2b_branch2a/truediv
# bn2b_branch2a/mul
# bn2b_branch2a/AssignMovingAvg/decay
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/zeros
# bn2b_branch2a/moving_mean/biased
# bn2b_branch2a/moving_mean/biased/Assign
# bn2b_branch2a/moving_mean/biased/read
# bn2b_branch2a/moving_mean/local_step/Initializer/zeros
# bn2b_branch2a/moving_mean/local_step
# bn2b_branch2a/moving_mean/local_step/Assign
# bn2b_branch2a/moving_mean/local_step/read
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/sub
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/mul
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/bn2b_branch2a/moving_mean
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/AssignAdd/value
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/AssignAdd
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/read
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/sub_1/x
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/sub_1
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/read_1
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/Pow
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/sub_2/x
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/sub_2
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/truediv
# bn2b_branch2a/AssignMovingAvg/bn2b_branch2a/moving_mean/sub_3
# bn2b_branch2a/AssignMovingAvg
# bn2b_branch2a/AssignMovingAvg_1/decay
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/zeros
# bn2b_branch2a/moving_variance/biased
# bn2b_branch2a/moving_variance/biased/Assign
# bn2b_branch2a/moving_variance/biased/read
# bn2b_branch2a/moving_variance/local_step/Initializer/zeros
# bn2b_branch2a/moving_variance/local_step
# bn2b_branch2a/moving_variance/local_step/Assign
# bn2b_branch2a/moving_variance/local_step/read
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/sub
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/mul
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/bn2b_branch2a/moving_variance
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/AssignAdd/value
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/AssignAdd
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/read
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/sub_1/x
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/sub_1
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/read_1
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/Pow
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/sub_2/x
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/sub_2
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/truediv
# bn2b_branch2a/AssignMovingAvg_1/bn2b_branch2a/moving_variance/sub_3
# bn2b_branch2a/AssignMovingAvg_1
# bn2b_branch2a/cond/Switch
# bn2b_branch2a/cond/switch_t
# bn2b_branch2a/cond/switch_f
# bn2b_branch2a/cond/pred_id
# bn2b_branch2a/cond/Switch_1
# bn2b_branch2a/cond/FusedBatchNorm
# bn2b_branch2a/cond/FusedBatchNorm/Switch
# bn2b_branch2a/cond/FusedBatchNorm/Switch_1
# bn2b_branch2a/cond/FusedBatchNorm/Switch_2
# bn2b_branch2a/cond/FusedBatchNorm/Switch_3
# bn2b_branch2a/cond/FusedBatchNorm/Switch_4
# bn2b_branch2a/cond/Merge
# activation_5/Relu
# res2b_branch2b/truncated_normal/shape
# res2b_branch2b/truncated_normal/mean
# res2b_branch2b/truncated_normal/stddev
# res2b_branch2b/truncated_normal/TruncatedNormal
# res2b_branch2b/truncated_normal/mul
# res2b_branch2b/truncated_normal
# res2b_branch2b/kernel
# res2b_branch2b/kernel/Assign
# res2b_branch2b/kernel/read
# res2b_branch2b/Const
# res2b_branch2b/bias
# res2b_branch2b/bias/Assign
# res2b_branch2b/bias/read
# res2b_branch2b/convolution/dilation_rate
# res2b_branch2b/convolution
# res2b_branch2b/BiasAdd
# bn2b_branch2b/Const
# bn2b_branch2b/gamma
# bn2b_branch2b/gamma/Assign
# bn2b_branch2b/gamma/read
# bn2b_branch2b/Const_1
# bn2b_branch2b/beta
# bn2b_branch2b/beta/Assign
# bn2b_branch2b/beta/read
# bn2b_branch2b/Const_2
# bn2b_branch2b/moving_mean
# bn2b_branch2b/moving_mean/Assign
# bn2b_branch2b/moving_mean/read
# bn2b_branch2b/Const_3
# bn2b_branch2b/moving_variance
# bn2b_branch2b/moving_variance/Assign
# bn2b_branch2b/moving_variance/read
# bn2b_branch2b/Const_4
# bn2b_branch2b/Const_5
# bn2b_branch2b/FusedBatchNorm
# bn2b_branch2b/Shape
# bn2b_branch2b/strided_slice/stack
# bn2b_branch2b/strided_slice/stack_1
# bn2b_branch2b/strided_slice/stack_2
# bn2b_branch2b/strided_slice
# bn2b_branch2b/Shape_1
# bn2b_branch2b/strided_slice_1/stack
# bn2b_branch2b/strided_slice_1/stack_1
# bn2b_branch2b/strided_slice_1/stack_2
# bn2b_branch2b/strided_slice_1
# bn2b_branch2b/Shape_2
# bn2b_branch2b/strided_slice_2/stack
# bn2b_branch2b/strided_slice_2/stack_1
# bn2b_branch2b/strided_slice_2/stack_2
# bn2b_branch2b/strided_slice_2
# bn2b_branch2b/Rank/packed
# bn2b_branch2b/Rank
# bn2b_branch2b/range/start
# bn2b_branch2b/range/delta
# bn2b_branch2b/range
# bn2b_branch2b/Prod/input
# bn2b_branch2b/Prod
# bn2b_branch2b/Cast
# bn2b_branch2b/sub/y
# bn2b_branch2b/sub
# bn2b_branch2b/truediv
# bn2b_branch2b/mul
# bn2b_branch2b/AssignMovingAvg/decay
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/zeros
# bn2b_branch2b/moving_mean/biased
# bn2b_branch2b/moving_mean/biased/Assign
# bn2b_branch2b/moving_mean/biased/read
# bn2b_branch2b/moving_mean/local_step/Initializer/zeros
# bn2b_branch2b/moving_mean/local_step
# bn2b_branch2b/moving_mean/local_step/Assign
# bn2b_branch2b/moving_mean/local_step/read
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/sub
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/mul
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/bn2b_branch2b/moving_mean
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/AssignAdd/value
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/AssignAdd
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/read
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/sub_1/x
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/sub_1
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/read_1
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/Pow
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/sub_2/x
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/sub_2
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/truediv
# bn2b_branch2b/AssignMovingAvg/bn2b_branch2b/moving_mean/sub_3
# bn2b_branch2b/AssignMovingAvg
# bn2b_branch2b/AssignMovingAvg_1/decay
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/zeros
# bn2b_branch2b/moving_variance/biased
# bn2b_branch2b/moving_variance/biased/Assign
# bn2b_branch2b/moving_variance/biased/read
# bn2b_branch2b/moving_variance/local_step/Initializer/zeros
# bn2b_branch2b/moving_variance/local_step
# bn2b_branch2b/moving_variance/local_step/Assign
# bn2b_branch2b/moving_variance/local_step/read
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/sub
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/mul
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/bn2b_branch2b/moving_variance
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/AssignAdd/value
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/AssignAdd
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/read
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/sub_1/x
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/sub_1
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/read_1
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/Pow
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/sub_2/x
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/sub_2
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/truediv
# bn2b_branch2b/AssignMovingAvg_1/bn2b_branch2b/moving_variance/sub_3
# bn2b_branch2b/AssignMovingAvg_1
# bn2b_branch2b/cond/Switch
# bn2b_branch2b/cond/switch_t
# bn2b_branch2b/cond/switch_f
# bn2b_branch2b/cond/pred_id
# bn2b_branch2b/cond/Switch_1
# bn2b_branch2b/cond/FusedBatchNorm
# bn2b_branch2b/cond/FusedBatchNorm/Switch
# bn2b_branch2b/cond/FusedBatchNorm/Switch_1
# bn2b_branch2b/cond/FusedBatchNorm/Switch_2
# bn2b_branch2b/cond/FusedBatchNorm/Switch_3
# bn2b_branch2b/cond/FusedBatchNorm/Switch_4
# bn2b_branch2b/cond/Merge
# activation_6/Relu
# res2b_branch2c/truncated_normal/shape
# res2b_branch2c/truncated_normal/mean
# res2b_branch2c/truncated_normal/stddev
# res2b_branch2c/truncated_normal/TruncatedNormal
# res2b_branch2c/truncated_normal/mul
# res2b_branch2c/truncated_normal
# res2b_branch2c/kernel
# res2b_branch2c/kernel/Assign
# res2b_branch2c/kernel/read
# res2b_branch2c/Const
# res2b_branch2c/bias
# res2b_branch2c/bias/Assign
# res2b_branch2c/bias/read
# res2b_branch2c/convolution/dilation_rate
# res2b_branch2c/convolution
# res2b_branch2c/BiasAdd
# bn2b_branch2c/Const
# bn2b_branch2c/gamma
# bn2b_branch2c/gamma/Assign
# bn2b_branch2c/gamma/read
# bn2b_branch2c/Const_1
# bn2b_branch2c/beta
# bn2b_branch2c/beta/Assign
# bn2b_branch2c/beta/read
# bn2b_branch2c/Const_2
# bn2b_branch2c/moving_mean
# bn2b_branch2c/moving_mean/Assign
# bn2b_branch2c/moving_mean/read
# bn2b_branch2c/Const_3
# bn2b_branch2c/moving_variance
# bn2b_branch2c/moving_variance/Assign
# bn2b_branch2c/moving_variance/read
# bn2b_branch2c/Const_4
# bn2b_branch2c/Const_5
# bn2b_branch2c/FusedBatchNorm
# bn2b_branch2c/Shape
# bn2b_branch2c/strided_slice/stack
# bn2b_branch2c/strided_slice/stack_1
# bn2b_branch2c/strided_slice/stack_2
# bn2b_branch2c/strided_slice
# bn2b_branch2c/Shape_1
# bn2b_branch2c/strided_slice_1/stack
# bn2b_branch2c/strided_slice_1/stack_1
# bn2b_branch2c/strided_slice_1/stack_2
# bn2b_branch2c/strided_slice_1
# bn2b_branch2c/Shape_2
# bn2b_branch2c/strided_slice_2/stack
# bn2b_branch2c/strided_slice_2/stack_1
# bn2b_branch2c/strided_slice_2/stack_2
# bn2b_branch2c/strided_slice_2
# bn2b_branch2c/Rank/packed
# bn2b_branch2c/Rank
# bn2b_branch2c/range/start
# bn2b_branch2c/range/delta
# bn2b_branch2c/range
# bn2b_branch2c/Prod/input
# bn2b_branch2c/Prod
# bn2b_branch2c/Cast
# bn2b_branch2c/sub/y
# bn2b_branch2c/sub
# bn2b_branch2c/truediv
# bn2b_branch2c/mul
# bn2b_branch2c/AssignMovingAvg/decay
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/zeros
# bn2b_branch2c/moving_mean/biased
# bn2b_branch2c/moving_mean/biased/Assign
# bn2b_branch2c/moving_mean/biased/read
# bn2b_branch2c/moving_mean/local_step/Initializer/zeros
# bn2b_branch2c/moving_mean/local_step
# bn2b_branch2c/moving_mean/local_step/Assign
# bn2b_branch2c/moving_mean/local_step/read
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/sub
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/mul
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/bn2b_branch2c/moving_mean
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/AssignAdd/value
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/AssignAdd
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/read
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/sub_1/x
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/sub_1
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/read_1
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/Pow
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/sub_2/x
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/sub_2
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/truediv
# bn2b_branch2c/AssignMovingAvg/bn2b_branch2c/moving_mean/sub_3
# bn2b_branch2c/AssignMovingAvg
# bn2b_branch2c/AssignMovingAvg_1/decay
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/zeros
# bn2b_branch2c/moving_variance/biased
# bn2b_branch2c/moving_variance/biased/Assign
# bn2b_branch2c/moving_variance/biased/read
# bn2b_branch2c/moving_variance/local_step/Initializer/zeros
# bn2b_branch2c/moving_variance/local_step
# bn2b_branch2c/moving_variance/local_step/Assign
# bn2b_branch2c/moving_variance/local_step/read
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/sub
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/mul
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/bn2b_branch2c/moving_variance
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/AssignAdd/value
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/AssignAdd
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/read
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/sub_1/x
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/sub_1
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/read_1
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/Pow
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/sub_2/x
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/sub_2
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/truediv
# bn2b_branch2c/AssignMovingAvg_1/bn2b_branch2c/moving_variance/sub_3
# bn2b_branch2c/AssignMovingAvg_1
# bn2b_branch2c/cond/Switch
# bn2b_branch2c/cond/switch_t
# bn2b_branch2c/cond/switch_f
# bn2b_branch2c/cond/pred_id
# bn2b_branch2c/cond/Switch_1
# bn2b_branch2c/cond/FusedBatchNorm
# bn2b_branch2c/cond/FusedBatchNorm/Switch
# bn2b_branch2c/cond/FusedBatchNorm/Switch_1
# bn2b_branch2c/cond/FusedBatchNorm/Switch_2
# bn2b_branch2c/cond/FusedBatchNorm/Switch_3
# bn2b_branch2c/cond/FusedBatchNorm/Switch_4
# bn2b_branch2c/cond/Merge
# add_2/add
# activation_7/Relu
# res2c_branch2a/truncated_normal/shape
# res2c_branch2a/truncated_normal/mean
# res2c_branch2a/truncated_normal/stddev
# res2c_branch2a/truncated_normal/TruncatedNormal
# res2c_branch2a/truncated_normal/mul
# res2c_branch2a/truncated_normal
# res2c_branch2a/kernel
# res2c_branch2a/kernel/Assign
# res2c_branch2a/kernel/read
# res2c_branch2a/Const
# res2c_branch2a/bias
# res2c_branch2a/bias/Assign
# res2c_branch2a/bias/read
# res2c_branch2a/convolution/dilation_rate
# res2c_branch2a/convolution
# res2c_branch2a/BiasAdd
# bn2c_branch2a/Const
# bn2c_branch2a/gamma
# bn2c_branch2a/gamma/Assign
# bn2c_branch2a/gamma/read
# bn2c_branch2a/Const_1
# bn2c_branch2a/beta
# bn2c_branch2a/beta/Assign
# bn2c_branch2a/beta/read
# bn2c_branch2a/Const_2
# bn2c_branch2a/moving_mean
# bn2c_branch2a/moving_mean/Assign
# bn2c_branch2a/moving_mean/read
# bn2c_branch2a/Const_3
# bn2c_branch2a/moving_variance
# bn2c_branch2a/moving_variance/Assign
# bn2c_branch2a/moving_variance/read
# bn2c_branch2a/Const_4
# bn2c_branch2a/Const_5
# bn2c_branch2a/FusedBatchNorm
# bn2c_branch2a/Shape
# bn2c_branch2a/strided_slice/stack
# bn2c_branch2a/strided_slice/stack_1
# bn2c_branch2a/strided_slice/stack_2
# bn2c_branch2a/strided_slice
# bn2c_branch2a/Shape_1
# bn2c_branch2a/strided_slice_1/stack
# bn2c_branch2a/strided_slice_1/stack_1
# bn2c_branch2a/strided_slice_1/stack_2
# bn2c_branch2a/strided_slice_1
# bn2c_branch2a/Shape_2
# bn2c_branch2a/strided_slice_2/stack
# bn2c_branch2a/strided_slice_2/stack_1
# bn2c_branch2a/strided_slice_2/stack_2
# bn2c_branch2a/strided_slice_2
# bn2c_branch2a/Rank/packed
# bn2c_branch2a/Rank
# bn2c_branch2a/range/start
# bn2c_branch2a/range/delta
# bn2c_branch2a/range
# bn2c_branch2a/Prod/input
# bn2c_branch2a/Prod
# bn2c_branch2a/Cast
# bn2c_branch2a/sub/y
# bn2c_branch2a/sub
# bn2c_branch2a/truediv
# bn2c_branch2a/mul
# bn2c_branch2a/AssignMovingAvg/decay
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/zeros
# bn2c_branch2a/moving_mean/biased
# bn2c_branch2a/moving_mean/biased/Assign
# bn2c_branch2a/moving_mean/biased/read
# bn2c_branch2a/moving_mean/local_step/Initializer/zeros
# bn2c_branch2a/moving_mean/local_step
# bn2c_branch2a/moving_mean/local_step/Assign
# bn2c_branch2a/moving_mean/local_step/read
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/sub
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/mul
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/bn2c_branch2a/moving_mean
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/AssignAdd/value
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/AssignAdd
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/read
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/sub_1/x
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/sub_1
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/read_1
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/Pow
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/sub_2/x
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/sub_2
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/truediv
# bn2c_branch2a/AssignMovingAvg/bn2c_branch2a/moving_mean/sub_3
# bn2c_branch2a/AssignMovingAvg
# bn2c_branch2a/AssignMovingAvg_1/decay
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/zeros
# bn2c_branch2a/moving_variance/biased
# bn2c_branch2a/moving_variance/biased/Assign
# bn2c_branch2a/moving_variance/biased/read
# bn2c_branch2a/moving_variance/local_step/Initializer/zeros
# bn2c_branch2a/moving_variance/local_step
# bn2c_branch2a/moving_variance/local_step/Assign
# bn2c_branch2a/moving_variance/local_step/read
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/sub
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/mul
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/bn2c_branch2a/moving_variance
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/AssignAdd/value
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/AssignAdd
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/read
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/sub_1/x
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/sub_1
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/read_1
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/Pow
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/sub_2/x
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/sub_2
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/truediv
# bn2c_branch2a/AssignMovingAvg_1/bn2c_branch2a/moving_variance/sub_3
# bn2c_branch2a/AssignMovingAvg_1
# bn2c_branch2a/cond/Switch
# bn2c_branch2a/cond/switch_t
# bn2c_branch2a/cond/switch_f
# bn2c_branch2a/cond/pred_id
# bn2c_branch2a/cond/Switch_1
# bn2c_branch2a/cond/FusedBatchNorm
# bn2c_branch2a/cond/FusedBatchNorm/Switch
# bn2c_branch2a/cond/FusedBatchNorm/Switch_1
# bn2c_branch2a/cond/FusedBatchNorm/Switch_2
# bn2c_branch2a/cond/FusedBatchNorm/Switch_3
# bn2c_branch2a/cond/FusedBatchNorm/Switch_4
# bn2c_branch2a/cond/Merge
# activation_8/Relu
# res2c_branch2b/truncated_normal/shape
# res2c_branch2b/truncated_normal/mean
# res2c_branch2b/truncated_normal/stddev
# res2c_branch2b/truncated_normal/TruncatedNormal
# res2c_branch2b/truncated_normal/mul
# res2c_branch2b/truncated_normal
# res2c_branch2b/kernel
# res2c_branch2b/kernel/Assign
# res2c_branch2b/kernel/read
# res2c_branch2b/Const
# res2c_branch2b/bias
# res2c_branch2b/bias/Assign
# res2c_branch2b/bias/read
# res2c_branch2b/convolution/dilation_rate
# res2c_branch2b/convolution
# res2c_branch2b/BiasAdd
# bn2c_branch2b/Const
# bn2c_branch2b/gamma
# bn2c_branch2b/gamma/Assign
# bn2c_branch2b/gamma/read
# bn2c_branch2b/Const_1
# bn2c_branch2b/beta
# bn2c_branch2b/beta/Assign
# bn2c_branch2b/beta/read
# bn2c_branch2b/Const_2
# bn2c_branch2b/moving_mean
# bn2c_branch2b/moving_mean/Assign
# bn2c_branch2b/moving_mean/read
# bn2c_branch2b/Const_3
# bn2c_branch2b/moving_variance
# bn2c_branch2b/moving_variance/Assign
# bn2c_branch2b/moving_variance/read
# bn2c_branch2b/Const_4
# bn2c_branch2b/Const_5
# bn2c_branch2b/FusedBatchNorm
# bn2c_branch2b/Shape
# bn2c_branch2b/strided_slice/stack
# bn2c_branch2b/strided_slice/stack_1
# bn2c_branch2b/strided_slice/stack_2
# bn2c_branch2b/strided_slice
# bn2c_branch2b/Shape_1
# bn2c_branch2b/strided_slice_1/stack
# bn2c_branch2b/strided_slice_1/stack_1
# bn2c_branch2b/strided_slice_1/stack_2
# bn2c_branch2b/strided_slice_1
# bn2c_branch2b/Shape_2
# bn2c_branch2b/strided_slice_2/stack
# bn2c_branch2b/strided_slice_2/stack_1
# bn2c_branch2b/strided_slice_2/stack_2
# bn2c_branch2b/strided_slice_2
# bn2c_branch2b/Rank/packed
# bn2c_branch2b/Rank
# bn2c_branch2b/range/start
# bn2c_branch2b/range/delta
# bn2c_branch2b/range
# bn2c_branch2b/Prod/input
# bn2c_branch2b/Prod
# bn2c_branch2b/Cast
# bn2c_branch2b/sub/y
# bn2c_branch2b/sub
# bn2c_branch2b/truediv
# bn2c_branch2b/mul
# bn2c_branch2b/AssignMovingAvg/decay
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/zeros
# bn2c_branch2b/moving_mean/biased
# bn2c_branch2b/moving_mean/biased/Assign
# bn2c_branch2b/moving_mean/biased/read
# bn2c_branch2b/moving_mean/local_step/Initializer/zeros
# bn2c_branch2b/moving_mean/local_step
# bn2c_branch2b/moving_mean/local_step/Assign
# bn2c_branch2b/moving_mean/local_step/read
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/sub
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/mul
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/bn2c_branch2b/moving_mean
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/AssignAdd/value
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/AssignAdd
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/read
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/sub_1/x
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/sub_1
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/read_1
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/Pow
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/sub_2/x
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/sub_2
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/truediv
# bn2c_branch2b/AssignMovingAvg/bn2c_branch2b/moving_mean/sub_3
# bn2c_branch2b/AssignMovingAvg
# bn2c_branch2b/AssignMovingAvg_1/decay
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/zeros
# bn2c_branch2b/moving_variance/biased
# bn2c_branch2b/moving_variance/biased/Assign
# bn2c_branch2b/moving_variance/biased/read
# bn2c_branch2b/moving_variance/local_step/Initializer/zeros
# bn2c_branch2b/moving_variance/local_step
# bn2c_branch2b/moving_variance/local_step/Assign
# bn2c_branch2b/moving_variance/local_step/read
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/sub
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/mul
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/bn2c_branch2b/moving_variance
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/AssignAdd/value
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/AssignAdd
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/read
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/sub_1/x
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/sub_1
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/read_1
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/Pow
# bn2c_branch2b/AssignMovingAvg_1/bn2c_branch2b/moving_variance/sub_2/x
# ...
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/AssignAdd
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/read
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/sub_1/x
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/sub_1
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/read_1
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/Pow
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/sub_2/x
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/sub_2
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/truediv
# batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/sub_3
# batch_normalization_5/AssignMovingAvg
# batch_normalization_5/AssignMovingAvg_1/decay
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/zeros
# batch_normalization_5/moving_variance/biased
# batch_normalization_5/moving_variance/biased/Assign
# batch_normalization_5/moving_variance/biased/read
# batch_normalization_5/moving_variance/local_step/Initializer/zeros
# batch_normalization_5/moving_variance/local_step
# batch_normalization_5/moving_variance/local_step/Assign
# batch_normalization_5/moving_variance/local_step/read
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/sub
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/mul
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/batch_normalization_5/moving_variance
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/AssignAdd/value
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/AssignAdd
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/read
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/sub_1/x
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/sub_1
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/read_1
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/Pow
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/sub_2/x
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/sub_2
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/truediv
# batch_normalization_5/AssignMovingAvg_1/batch_normalization_5/moving_variance/sub_3
# batch_normalization_5/AssignMovingAvg_1
# batch_normalization_5/cond/Switch
# batch_normalization_5/cond/switch_t
# batch_normalization_5/cond/switch_f
# batch_normalization_5/cond/pred_id
# batch_normalization_5/cond/Switch_1
# batch_normalization_5/cond/FusedBatchNorm
# batch_normalization_5/cond/FusedBatchNorm/Switch
# batch_normalization_5/cond/FusedBatchNorm/Switch_1
# batch_normalization_5/cond/FusedBatchNorm/Switch_2
# batch_normalization_5/cond/FusedBatchNorm/Switch_3
# batch_normalization_5/cond/FusedBatchNorm/Switch_4
# batch_normalization_5/cond/Merge
# activation_54/Relu
# conv2d_9/random_uniform/shape
# conv2d_9/random_uniform/min
# conv2d_9/random_uniform/max
# conv2d_9/random_uniform/RandomUniform
# conv2d_9/random_uniform/sub
# conv2d_9/random_uniform/mul
# conv2d_9/random_uniform
# conv2d_9/kernel
# conv2d_9/kernel/Assign
# conv2d_9/kernel/read
# conv2d_9/Const
# conv2d_9/bias
# conv2d_9/bias/Assign
# conv2d_9/bias/read
# conv2d_9/convolution/dilation_rate
# conv2d_9/convolution
# conv2d_9/BiasAdd
# Const
# mul
# resize_image_9/strided_slice/stack
# resize_image_9/strided_slice/stack_1
# resize_image_9/strided_slice/stack_2
# resize_image_9/strided_slice
# resize_image_9/strided_slice_1/stack
# resize_image_9/strided_slice_1/stack_1
# resize_image_9/strided_slice_1/stack_2
# resize_image_9/strided_slice_1
# resize_image_9/resize_images/size
# resize_image_9/resize_images/ResizeBilinear
# activation_55/Sigmoid
# Placeholder_318
# Assign_318
# Placeholder_319
# Assign_319
# Placeholder_320
# Assign_320
# Placeholder_321
# Assign_321
# Placeholder_322
# Assign_322
# Placeholder_323
# Assign_323
# Placeholder_324
# Assign_324
# Placeholder_325
# Assign_325
# Placeholder_326
# Assign_326
# Placeholder_327
# Assign_327
# Placeholder_328
# Assign_328
# Placeholder_329
# Assign_329
# Placeholder_330
# Assign_330
# Placeholder_331
# Assign_331
# Placeholder_332
# Assign_332
# Placeholder_333
# Assign_333
# Placeholder_334
# Assign_334
# Placeholder_335
# Assign_335
# Placeholder_336
# Assign_336
# Placeholder_337
# Assign_337
# Placeholder_338
# Assign_338
# Placeholder_339
# Assign_339
# Placeholder_340
# Assign_340
# Placeholder_341
# Assign_341
# Placeholder_342
# Assign_342
# Placeholder_343
# Assign_343
# Placeholder_344
# Assign_344
# Placeholder_345
# Assign_345
# Placeholder_346
# Assign_346
# Placeholder_347
# Assign_347
# Placeholder_348
# Assign_348
# Placeholder_349
# Assign_349
# Placeholder_350
# Assign_350
# Placeholder_351
# Assign_351
# Placeholder_352
# Assign_352
# Placeholder_353
# Assign_353
# Placeholder_354
# Assign_354
# Placeholder_355
# Assign_355
# IsVariableInitialized_524
# IsVariableInitialized_525
# IsVariableInitialized_526
# IsVariableInitialized_527
# IsVariableInitialized_528
# IsVariableInitialized_529
# IsVariableInitialized_530
# IsVariableInitialized_531
# IsVariableInitialized_532
# IsVariableInitialized_533
# IsVariableInitialized_534
# IsVariableInitialized_535
# IsVariableInitialized_536
# IsVariableInitialized_537
# IsVariableInitialized_538
# IsVariableInitialized_539
# IsVariableInitialized_540
# IsVariableInitialized_541
# IsVariableInitialized_542
# IsVariableInitialized_543
# IsVariableInitialized_544
# IsVariableInitialized_545
# IsVariableInitialized_546
# IsVariableInitialized_547
# IsVariableInitialized_548
# IsVariableInitialized_549
# IsVariableInitialized_550
# IsVariableInitialized_551
# IsVariableInitialized_552
# IsVariableInitialized_553
# IsVariableInitialized_554
# IsVariableInitialized_555
# IsVariableInitialized_556
# IsVariableInitialized_557
# IsVariableInitialized_558
# IsVariableInitialized_559
# IsVariableInitialized_560
# IsVariableInitialized_561
# IsVariableInitialized_562
# IsVariableInitialized_563
# IsVariableInitialized_564
# IsVariableInitialized_565
# IsVariableInitialized_566
# IsVariableInitialized_567
# IsVariableInitialized_568
# IsVariableInitialized_569
# IsVariableInitialized_570
# IsVariableInitialized_571
# IsVariableInitialized_572
# IsVariableInitialized_573
# IsVariableInitialized_574
# IsVariableInitialized_575
# IsVariableInitialized_576
# IsVariableInitialized_577
# IsVariableInitialized_578
# IsVariableInitialized_579
# IsVariableInitialized_580
# IsVariableInitialized_581
# init_1
# group_deps
# save/Const
# save/SaveV2/tensor_names
# save/SaveV2/shape_and_slices
# save/SaveV2
# save/control_dependency
# save/RestoreV2/tensor_names
# save/RestoreV2/shape_and_slices
# save/RestoreV2
# save/Assign
# save/Assign_1
# save/Assign_2
# save/Assign_3
# save/Assign_4
# save/Assign_5
# save/Assign_6
# save/Assign_7
# save/Assign_8
# save/Assign_9
# save/Assign_10
# save/Assign_11
# save/Assign_12
# save/Assign_13
# save/Assign_14
# save/Assign_15
# save/Assign_16
# save/Assign_17
# save/Assign_18
# save/Assign_19
# save/Assign_20
# save/Assign_21
# save/Assign_22
# save/Assign_23
# save/Assign_24
# save/Assign_25
# save/Assign_26
# save/Assign_27
# save/Assign_28
# save/Assign_29
# save/Assign_30
# save/Assign_31
# save/Assign_32
# save/Assign_33
# save/Assign_34
# save/Assign_35
# save/Assign_36
# save/Assign_37
# save/Assign_38
# save/Assign_39
# save/Assign_40
# save/Assign_41
# save/Assign_42
# save/Assign_43
# save/Assign_44
# save/Assign_45
# save/Assign_46
# save/Assign_47
# save/Assign_48
# save/Assign_49
# save/Assign_50
# save/Assign_51
# save/Assign_52
# save/Assign_53
# save/Assign_54
# save/Assign_55
# save/Assign_56
# save/Assign_57
# save/Assign_58
# save/Assign_59
# save/Assign_60
# save/Assign_61
# save/Assign_62
# save/Assign_63
# save/Assign_64
# save/Assign_65
# save/Assign_66
# save/Assign_67
# save/Assign_68
# save/Assign_69
# save/Assign_70
# save/Assign_71
# save/Assign_72
# save/Assign_73
# save/Assign_74
# save/Assign_75
# save/Assign_76
# save/Assign_77
# save/Assign_78
# save/Assign_79
# save/Assign_80
# save/Assign_81
# save/Assign_82
# save/Assign_83
# save/Assign_84
# save/Assign_85
# save/Assign_86
# save/Assign_87
# save/Assign_88
# save/Assign_89
# save/Assign_90
# save/Assign_91
# save/Assign_92
# save/Assign_93
# save/Assign_94
# save/Assign_95
# save/Assign_96
# save/Assign_97
# save/Assign_98
# save/Assign_99
# save/Assign_100
# save/Assign_101
# save/Assign_102
# save/Assign_103
# save/Assign_104
# save/Assign_105
# save/Assign_106
# save/Assign_107
# save/Assign_108
# save/Assign_109
# save/Assign_110
# save/Assign_111
# save/Assign_112
# save/Assign_113
# save/Assign_114
# save/Assign_115
# save/Assign_116
# save/Assign_117
# save/Assign_118
# save/Assign_119
# save/Assign_120
# save/Assign_121
# save/Assign_122
# save/Assign_123
# save/Assign_124
# save/Assign_125
# save/Assign_126
# save/Assign_127
# save/Assign_128
# save/Assign_129
# save/Assign_130
# save/Assign_131
# save/Assign_132
# save/Assign_133
# save/Assign_134
# save/Assign_135
# save/Assign_136
# save/Assign_137
# save/Assign_138
# save/Assign_139
# save/Assign_140
# save/Assign_141
# save/Assign_142
# save/Assign_143
# save/Assign_144
# save/Assign_145
# save/Assign_146
# save/Assign_147
# save/Assign_148
# save/Assign_149
# save/Assign_150
# save/Assign_151
# save/Assign_152
# save/Assign_153
# save/Assign_154
# save/Assign_155
# save/Assign_156
# save/Assign_157
# save/Assign_158
# save/Assign_159
# save/Assign_160
# save/Assign_161
# save/Assign_162
# save/Assign_163
# save/Assign_164
# save/Assign_165
# save/Assign_166
# save/Assign_167
# save/Assign_168
# save/Assign_169
# save/Assign_170
# save/Assign_171
# save/Assign_172
# save/Assign_173
# save/Assign_174
# save/Assign_175
# save/Assign_176
# save/Assign_177
# save/Assign_178
# save/Assign_179
# save/Assign_180
# save/Assign_181
# save/Assign_182
# save/Assign_183
# save/Assign_184
# save/Assign_185
# save/Assign_186
# save/Assign_187
# save/Assign_188
# save/Assign_189
# save/Assign_190
# save/Assign_191
# save/Assign_192
# save/Assign_193
# save/Assign_194
# save/Assign_195
# save/Assign_196
# save/Assign_197
# save/Assign_198
# save/Assign_199
# save/Assign_200
# save/Assign_201
# save/Assign_202
# save/Assign_203
# save/Assign_204
# save/Assign_205
# save/Assign_206
# save/Assign_207
# save/Assign_208
# save/Assign_209
# save/Assign_210
# save/Assign_211
# save/Assign_212
# save/Assign_213
# save/Assign_214
# save/Assign_215
# save/Assign_216
# save/Assign_217
# save/Assign_218
# save/Assign_219
# save/Assign_220
# save/Assign_221
# save/Assign_222
# save/Assign_223
# save/Assign_224
# save/Assign_225
# save/Assign_226
# save/Assign_227
# save/Assign_228
# save/Assign_229
# save/Assign_230
# save/Assign_231
# save/Assign_232
# save/Assign_233
# save/Assign_234
# save/Assign_235
# save/Assign_236
# save/Assign_237
# save/Assign_238
# save/Assign_239
# save/Assign_240
# save/Assign_241
# save/Assign_242
# save/Assign_243
# save/Assign_244
# save/Assign_245
# save/Assign_246
# save/Assign_247
# save/Assign_248
# save/Assign_249
# save/Assign_250
# save/Assign_251
# save/Assign_252
# save/Assign_253
# save/Assign_254
# save/Assign_255
# save/Assign_256
# save/Assign_257
# save/Assign_258
# save/Assign_259
# save/Assign_260
# save/Assign_261
# save/Assign_262
# save/Assign_263
# save/Assign_264
# save/Assign_265
# save/Assign_266
# save/Assign_267
# save/Assign_268
# save/Assign_269
# save/Assign_270
# save/Assign_271
# save/Assign_272
# save/Assign_273
# save/Assign_274
# save/Assign_275
# save/Assign_276
# save/Assign_277
# save/Assign_278
# save/Assign_279
# save/Assign_280
# save/Assign_281
# save/Assign_282
# save/Assign_283
# save/Assign_284
# save/Assign_285
# save/Assign_286
# save/Assign_287
# save/Assign_288
# save/Assign_289
# save/Assign_290
# save/Assign_291
# save/Assign_292
# save/Assign_293
# save/Assign_294
# save/Assign_295
# save/Assign_296
# save/Assign_297
# save/Assign_298
# save/Assign_299
# save/Assign_300
# save/Assign_301
# save/Assign_302
# save/Assign_303
# save/Assign_304
# save/Assign_305
# save/Assign_306
# save/Assign_307
# save/Assign_308
# save/Assign_309
# save/Assign_310
# save/Assign_311
# save/Assign_312
# save/Assign_313
# save/Assign_314
# save/Assign_315
# save/Assign_316
# save/Assign_317
# save/Assign_318
# save/Assign_319
# save/Assign_320
# save/Assign_321
# save/Assign_322
# save/Assign_323
# save/Assign_324
# save/Assign_325
# save/Assign_326
# save/Assign_327
# save/Assign_328
# save/Assign_329
# save/Assign_330
# save/Assign_331
# save/Assign_332
# save/Assign_333
# save/Assign_334
# save/Assign_335
# save/Assign_336
# save/Assign_337
# save/Assign_338
# save/Assign_339
# save/Assign_340
# save/Assign_341
# save/Assign_342
# save/Assign_343
# save/Assign_344
# save/Assign_345
# save/Assign_346
# save/Assign_347
# save/Assign_348
# save/Assign_349
# save/Assign_350
# save/Assign_351
# save/Assign_352
# save/Assign_353
# save/Assign_354
# save/Assign_355
# save/Assign_356
# save/Assign_357
# save/Assign_358
# save/Assign_359
# save/Assign_360
# save/Assign_361
# save/Assign_362
# save/Assign_363
# save/Assign_364
# save/Assign_365
# save/Assign_366
# save/Assign_367
# save/Assign_368
# save/Assign_369
# save/Assign_370
# save/Assign_371
# save/Assign_372
# save/Assign_373
# save/Assign_374
# save/Assign_375
# save/Assign_376
# save/Assign_377
# save/Assign_378
# save/Assign_379
# save/Assign_380
# save/Assign_381
# save/Assign_382
# save/Assign_383
# save/Assign_384
# save/Assign_385
# save/Assign_386
# save/Assign_387
# save/Assign_388
# save/Assign_389
# save/Assign_390
# save/Assign_391
# save/Assign_392
# save/Assign_393
# save/Assign_394
# save/Assign_395
# save/Assign_396
# save/Assign_397
# save/Assign_398
# save/Assign_399
# save/Assign_400
# save/Assign_401
# save/Assign_402
# save/Assign_403
# save/Assign_404
# save/Assign_405
# save/Assign_406
# save/Assign_407
# save/Assign_408
# save/Assign_409
# save/Assign_410
# save/Assign_411
# save/Assign_412
# save/Assign_413
# save/Assign_414
# save/Assign_415
# save/Assign_416
# save/Assign_417
# save/Assign_418
# save/Assign_419
# save/Assign_420
# save/Assign_421
# save/Assign_422
# save/Assign_423
# save/Assign_424
# save/Assign_425
# save/Assign_426
# save/Assign_427
# save/Assign_428
# save/Assign_429
# save/Assign_430
# save/Assign_431
# save/Assign_432
# save/Assign_433
# save/Assign_434
# save/Assign_435
# save/Assign_436
# save/Assign_437
# save/Assign_438
# save/Assign_439
# save/Assign_440
# save/Assign_441
# save/Assign_442
# save/Assign_443
# save/Assign_444
# save/Assign_445
# save/Assign_446
# save/Assign_447
# save/Assign_448
# save/Assign_449
# save/Assign_450
# save/Assign_451
# save/Assign_452
# save/Assign_453
# save/Assign_454
# save/Assign_455
# save/Assign_456
# save/Assign_457
# save/Assign_458
# save/Assign_459
# save/Assign_460
# save/Assign_461
# save/Assign_462
# save/Assign_463
# save/Assign_464
# save/Assign_465
# save/Assign_466
# save/Assign_467
# save/Assign_468
# save/Assign_469
# save/Assign_470
# save/Assign_471
# save/Assign_472
# save/Assign_473
# save/Assign_474
# save/Assign_475
# save/Assign_476
# save/Assign_477
# save/Assign_478
# save/Assign_479
# save/Assign_480
# save/Assign_481
# save/Assign_482
# save/Assign_483
# save/Assign_484
# save/Assign_485
# save/Assign_486
# save/Assign_487
# save/Assign_488
# save/Assign_489
# save/Assign_490
# save/Assign_491
# save/Assign_492
# save/Assign_493
# save/Assign_494
# save/Assign_495
# save/Assign_496
# save/Assign_497
# save/Assign_498
# save/Assign_499
# save/Assign_500
# save/Assign_501
# save/Assign_502
# save/Assign_503
# save/Assign_504
# save/Assign_505
# save/Assign_506
# save/Assign_507
# save/Assign_508
# save/Assign_509
# save/Assign_510
# save/Assign_511
# save/Assign_512
# save/Assign_513
# save/Assign_514
# save/Assign_515
# save/Assign_516
# save/Assign_517
# save/Assign_518
# save/Assign_519
# save/Assign_520
# save/Assign_521
# save/Assign_522
# save/Assign_523
# save/Assign_524
# save/Assign_525
# save/Assign_526
# save/Assign_527
# save/Assign_528
# save/Assign_529
# save/Assign_530
# save/Assign_531
# save/Assign_532
# save/Assign_533
# save/Assign_534
# save/Assign_535
# save/Assign_536
# save/Assign_537
# save/Assign_538
# save/Assign_539
# save/Assign_540
# save/Assign_541
# save/Assign_542
# save/Assign_543
# save/Assign_544
# save/Assign_545
# save/Assign_546
# save/Assign_547
# save/Assign_548
# save/Assign_549
# save/Assign_550
# save/Assign_551
# save/Assign_552
# save/Assign_553
# save/Assign_554
# save/Assign_555
# save/Assign_556
# save/Assign_557
# save/Assign_558
# save/Assign_559
# save/Assign_560
# save/Assign_561
# save/Assign_562
# save/Assign_563
# save/Assign_564
# save/Assign_565
# save/Assign_566
# save/Assign_567
# save/Assign_568
# save/Assign_569
# save/Assign_570
# save/Assign_571
# save/Assign_572
# save/Assign_573
# save/Assign_574
# save/Assign_575
# save/Assign_576
# save/Assign_577
# save/Assign_578
# save/Assign_579
# save/Assign_580
# save/Assign_581
# save/Assign_582
# save/Assign_583
# save/Assign_584
# save/Assign_585
# save/Assign_586
# save/Assign_587
# save/restore_all

# %%
from tensorflow.python.tools import freeze_graph
freeze_graph.freeze_graph(input_checkpoint = './tf/resnet50.ckpt',
                          input_meta_graph = './tf/resnet50.ckpt.meta',
                          output_graph = 'psenet.pb',
                          output_node_names = 'activation_55/Sigmoid',
                          clear_devices = True,
                          input_graph ='',
                          input_saver = '',
                          input_binary = True,
                          restore_op_name = 'save/restore_all',
                          filename_tensor_name = 'save/Const:0',
                          initializer_nodes = '')
# Out:
# WARNING:tensorflow:From /anaconda3/envs/tf/lib/python3.5/site-packages/tensorflow/python/tools/freeze_graph.py:264: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# Loaded meta graph file './tf/resnet50.ckpt.meta
# INFO:tensorflow:Restoring parameters from ./tf/resnet50.ckpt
# INFO:tensorflow:Froze 356 variables.
# INFO:tensorflow:Converted 356 variables to const ops.

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
sess = None
with tf.Graph().as_default():
    output_graph_def = tf.GraphDef()
    with open('psenet.pb','rb') as f :
        output_graph_def.ParseFromString(f.read())
        _= tf.import_graph_def(output_graph_def,name='')
        
    sess =  tf.Session()
    init = tf.global_variables_initializer()
    sess.run(init)

    ip = sess.graph.get_tensor_by_name("input_1:0")
    op = sess.graph.get_tensor_by_name("activation_55/Sigmoid:0")

# %%
MIN_LEN = 640
MAX_LEN = 1500
images = cv2.imread(r'./r1.png')
h,w = images.shape[0:2]

if(w<h):
    if(h<MIN_LEN):
        scale = 1.0 * MIN_LEN / h
        w = w * scale 
        h = MIN_LEN
    elif(h>MAX_LEN):
        scale = 1.0 * MAX_LEN / h 
        w = w * scale 
        h = MAX_LEN
elif(h<=w ):
    if(w<MIN_LEN):
        scale = 1.0 * MIN_LEN /w
        h = scale * h 
        w = MIN_LEN 
    elif(w>MAX_LEN):
        scale = 1.0 * MAX_LEN /w
        h = scale * w 
        h = MAX_LEN
        
w = int(w //32 * 32)
h = int(h//32 * 32)

scalex = images.shape[1] / w
scaley = images.shape[0] / h

images = cv2.resize(images,(w,h),cv2.INTER_AREA)
images = np.reshape(images,(1,h,w,3))   


res = sess.run([op], feed_dict={ip:images})

# %%
res1 = res[0][0]
print(res1.shape)
res1[res1>0.9]= 1
res1[res1<=0.9]= 0
newres1 = []
for i in range(3,5):
    n = np.logical_and(res1[:,:,5],res1[:,:,i]) * 255
    newres1.append(n)
newres1.append(res1[:,:,5]*255)     

from tool.utils import scale_expand_kernels ,fit_boundingRect_2
from tool.utils import text_porposcal

num_label,labelimage = scale_expand_kernels(newres1,filter=False)
rects = fit_boundingRect_2(num_label,labelimage)

g = text_porposcal(rects,labelimage.shape[1],max_dist=3,threshold_overlap_v=0.3)
rects = g.get_text_line()

imagetest = np.copy(images[0])

for rt in rects:
    cv2.rectangle(imagetest,(rt[0]*2,rt[1]*2-2),(rt[2]*2,rt[3]*2),(0,0,255),2)
plt.imshow(imagetest)
cv2.imwrite('test7.jpg',imagetest)
# Out:
# (736, 576, 6)
# True

# %%
import numpy as np 

a = [0] + [1,2,3]

# %%
a = np.array(a) / np.sum(a)

# %%
a = np.cumsum(a) * 10

# %%
a[-1] = 10

# %%
a
# Out:
# array([ 0.        ,  1.66666667,  5.        , 10.        ])

# %%
import os 
os.mkdir('Users/mahuichao/Documents/TableBank_data/Detection_data/Word/train_0')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-100-92891602f645> in <module>
#       1 import os
# ----> 2 os.mkdir('Users/mahuichao/Documents/TableBank_data/Detection_data/Word/train_0')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Users/mahuichao/Documents/TableBank_data/Detection_data/Word/train_0'

# %%
from collections import Counter

# %%
a = Counter([])

# %%
a
# Out:
# Counter()

# %%
b = a.most_common(1)

# %%
b
# Out:
# []
